# %% [markdown]
# # Tutorial for antigen-HLAII binding prediction with deepAntigen

# %% [markdown]
# This notebook introduces to predict antigen-HLAII binding using the deepAntigen method.

# %% [markdown]
# ## Import relevant packages

# %%
from deepAntigen.antigenHLAII import run_antigenHLAII_seq
from deepAntigen.antigenHLAII import run_antigenHLAII_atom
from deepAntigen.antigenHLAII.utils.antigenHLAII_preprocess import split_data, process_pdb_absolute, process_pdb_relative, calculate_distance
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os

# %% [markdown]
# ## Download antigen-HLAII data

# %%
#!wget https://github.com/JiangBioLab/deepAntigen/blob/main/test_antigenHLAII.zip
#!unzip test_antigenHLAII.zip

# %% [markdown]
# ## Inference anitgen-HLAII binding at the sequence level using deepAntigen

# %% [markdown]
# By utilizing parameters provided by us, you can directly predict antigen-HLAII binding, requiring only the preparation of the test dataset 'test.csv'.

# %%
df = run_antigenHLAII_seq.Inference('./test_antigenHLAII/Data/sequence/test.csv')
# Out:
# peptide:WYQXKPGQPPKLLIYKASTLE
# Prediction results have been saved to./antigenHLAII_Output/seq-level/pHLAII_predictions.csv

# %%
df
# Out:
#                      peptide     alpha_n      beta_n     score  label
# 0               QAGKEAEKLGQG  DPA1*01:03  DPB1*01:01  0.550992      1
# 1               TRVGINIFTRLR  DPA1*01:03  DPB1*01:01  0.511401      1
# 2               QVKRNAVPITPT  DPA1*01:03  DPB1*01:01  0.824243      1
# 3               ITAVTATSNEIK  DPA1*01:03  DPB1*01:01  0.614831      1
# 4               PAGKLKYFDKLN  DPA1*01:03  DPB1*01:01  0.969304      1
# ...                      ...         ...         ...       ...    ...
# 12688        PRNDRNVFSRLTSNQ   DRA*01:01  DRB5*01:01  0.016608      0
# 12689        DIPRVTALNRALVTV   DRA*01:01  DRB5*01:01  0.869845      0
# 12690       TTVGMNGKDKDIPSFT   DRA*01:01  DRB5*01:01  0.071086      0
# 12691  PVIYAGATSKNKMVSSAFTTE   DRA*01:01  DRB5*01:01  0.133924      0
# 12692  PTGLSLTSSMTLNLVTSADYK   DRA*01:01  DRB5*01:01  0.009127      0
#
# [12693 rows x 5 columns]

# %% [markdown]
# The column 'score' is binding probability predicted by deepAntigen. The column 'label' is optional. If 'label' is provided in 'test.csv', the results will include 'label'.

# %%
#Draw ROC curve
score_list=list(df['score'])
label_list=list(df['label'])
hhList=[]
LegendLabels=[]
plt.figure(figsize=(9,9))
font = {'weight' : 'normal',
'size'   : 20}
mpl.rc('font', **font)
fpr, tpr, thersholds = roc_curve(label_list, score_list, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot([0,1],[0,1],ls='dashed',lw=3, color='whitesmoke')
hh, = plt.plot(fpr, tpr, color='#0675B4', lw=3)
hhList.append(hh)
LegendLabels.append('deepAntigen_seq'+'(AUC:'+str(round(roc_auc,2))+')')
plt.xlabel('1-Specificity')
plt.ylabel('Sensitivity')
plt.title('ROC Curve')
legend=plt.legend(hhList,LegendLabels)
plt.show()

# %% [markdown]
# ## Train deepAntigen using sequence-level anitgen-HLAII binding data

# %% [markdown]
# Split the dataset for 10-fold cross-validation

# %%
split_data('./test_antigenHLAII/Data/sequence/train.csv',10)
# Out:
# Splited datasets have been saved to./test_antigenHLAII/Data/sequence/k_fold_dataset/

# %% [markdown]
# You can alter hyperparameters in 'config_seq.ini', and then start training.

# %%
run_antigenHLAII_seq.Train('./test_antigenHLAII/Data/sequence/k_fold_dataset/', config_path='./test_antigenHLAII/config_seq.ini')
# Out:
# Epoch:1 Train_loss:5.0439 ACC:0.6377 AUROC:0.6921 Precision:0.6156 Recall:0.7329 F1:0.6692 AUPR:0.6555
# Epoch:2 Train_loss:4.8022 ACC:0.6774 AUROC:0.7370 Precision:0.6442 Recall:0.7927 F1:0.7108 AUPR:0.6956
# Epoch:3 Train_loss:4.7291 ACC:0.6876 AUROC:0.7503 Precision:0.6551 Recall:0.7924 F1:0.7172 AUPR:0.7102
# Epoch:4 Train_loss:4.6657 ACC:0.6960 AUROC:0.7607 Precision:0.6635 Recall:0.7954 F1:0.7235 AUPR:0.7217
# Epoch:5 Train_loss:4.6192 ACC:0.7025 AUROC:0.7684 Precision:0.6704 Recall:0.7965 F1:0.7281 AUPR:0.7319
# Epoch:5 Val_loss:4.5034 ACC:0.7185 AUROC:0.7863 Precision:0.6762 Recall:0.8380 F1:0.7484 AUPR:0.7529
# ==> Saving model...
# Epoch:6 Train_loss:4.5996 ACC:0.7040 AUROC:0.7713 Precision:0.6715 Recall:0.7988 F1:0.7296 AUPR:0.7353
# Epoch:7 Train_loss:4.5730 ACC:0.7077 AUROC:0.7757 Precision:0.6759 Recall:0.7982 F1:0.7320 AUPR:0.7406
# Epoch:8 Train_loss:4.5489 ACC:0.7114 AUROC:0.7794 Precision:0.6798 Recall:0.7994 F1:0.7348 AUPR:0.7450
# Epoch:9 Train_loss:4.5361 ACC:0.7129 AUROC:0.7808 Precision:0.6811 Recall:0.8006 F1:0.7360 AUPR:0.7463
# Epoch:10 Train_loss:4.5291 ACC:0.7128 AUROC:0.7822 Precision:0.6811 Recall:0.8004 F1:0.7360 AUPR:0.7493
# Epoch:10 Val_loss:4.4336 ACC:0.7276 AUROC:0.7989 Precision:0.6814 Recall:0.8539 F1:0.7580 AUPR:0.7673
# ==> Saving model...
# ==> Saving model...
# Epoch:11 Train_loss:4.5170 ACC:0.7154 AUROC:0.7834 Precision:0.6846 Recall:0.7989 F1:0.7373 AUPR:0.7509
# Epoch:12 Train_loss:4.4965 ACC:0.7169 AUROC:0.7865 Precision:0.6856 Recall:0.8010 F1:0.7389 AUPR:0.7540
# Epoch:13 Train_loss:4.4877 ACC:0.7166 AUROC:0.7879 Precision:0.6863 Recall:0.7977 F1:0.7378 AUPR:0.7559
# Epoch:14 Train_loss:4.4813 ACC:0.7178 AUROC:0.7882 Precision:0.6864 Recall:0.8022 F1:0.7398 AUPR:0.7576
# Epoch:15 Train_loss:4.4694 ACC:0.7191 AUROC:0.7900 Precision:0.6882 Recall:0.8013 F1:0.7405 AUPR:0.7585
# Epoch:15 Val_loss:4.3768 ACC:0.7335 AUROC:0.8022 Precision:0.7026 Recall:0.8091 F1:0.7521 AUPR:0.7732
# ==> Saving model...
# Epoch:16 Train_loss:4.4709 ACC:0.7195 AUROC:0.7898 Precision:0.6879 Recall:0.8036 F1:0.7413 AUPR:0.7569
# Epoch:17 Train_loss:4.4670 ACC:0.7197 AUROC:0.7902 Precision:0.6885 Recall:0.8024 F1:0.7411 AUPR:0.7590
# Epoch:18 Train_loss:4.4468 ACC:0.7213 AUROC:0.7932 Precision:0.6905 Recall:0.8021 F1:0.7421 AUPR:0.7614
# Epoch:19 Train_loss:4.4384 ACC:0.7228 AUROC:0.7943 Precision:0.6916 Recall:0.8045 F1:0.7438 AUPR:0.7649
# Epoch:20 Train_loss:4.4436 ACC:0.7229 AUROC:0.7938 Precision:0.6921 Recall:0.8030 F1:0.7434 AUPR:0.7634
# Epoch:20 Val_loss:4.3101 ACC:0.7394 AUROC:0.8115 Precision:0.7191 Recall:0.7853 F1:0.7507 AUPR:0.7835
# ==> Saving model...
# ==> Saving model...
# Epoch:21 Train_loss:4.4311 ACC:0.7226 AUROC:0.7949 Precision:0.6920 Recall:0.8022 F1:0.7430 AUPR:0.7647
# Epoch:22 Train_loss:4.4196 ACC:0.7245 AUROC:0.7962 Precision:0.6931 Recall:0.8057 F1:0.7452 AUPR:0.7652
# Epoch:23 Train_loss:4.4113 ACC:0.7257 AUROC:0.7978 Precision:0.6953 Recall:0.8033 F1:0.7454 AUPR:0.7682
# Epoch:24 Train_loss:4.4078 ACC:0.7269 AUROC:0.7980 Precision:0.6961 Recall:0.8057 F1:0.7469 AUPR:0.7682
# Epoch:25 Train_loss:4.4080 ACC:0.7263 AUROC:0.7978 Precision:0.6951 Recall:0.8065 F1:0.7466 AUPR:0.7670
# Epoch:25 Val_loss:4.3286 ACC:0.7358 AUROC:0.8090 Precision:0.6990 Recall:0.8287 F1:0.7583 AUPR:0.7825
# Epoch:26 Train_loss:4.3925 ACC:0.7266 AUROC:0.8006 Precision:0.6963 Recall:0.8037 F1:0.7462 AUPR:0.7720
# Epoch:27 Train_loss:4.3788 ACC:0.7294 AUROC:0.8019 Precision:0.6986 Recall:0.8069 F1:0.7488 AUPR:0.7746
# Epoch:28 Train_loss:4.3780 ACC:0.7282 AUROC:0.8023 Precision:0.6980 Recall:0.8045 F1:0.7475 AUPR:0.7751
# Epoch:29 Train_loss:4.3515 ACC:0.7315 AUROC:0.8060 Precision:0.7017 Recall:0.8053 F1:0.7500 AUPR:0.7808
# Epoch:30 Train_loss:4.3063 ACC:0.7366 AUROC:0.8118 Precision:0.7084 Recall:0.8041 F1:0.7532 AUPR:0.7871
# Epoch:30 Val_loss:4.1804 ACC:0.7491 AUROC:0.8269 Precision:0.7155 Recall:0.8268 F1:0.7671 AUPR:0.8035
# ==> Saving model...
# ==> Saving model...
# Epoch:31 Train_loss:4.3101 ACC:0.7354 AUROC:0.8109 Precision:0.7067 Recall:0.8049 F1:0.7526 AUPR:0.7875
# Epoch:32 Train_loss:4.2905 ACC:0.7383 AUROC:0.8135 Precision:0.7095 Recall:0.8070 F1:0.7551 AUPR:0.7886
# Epoch:33 Train_loss:4.2855 ACC:0.7383 AUROC:0.8139 Precision:0.7103 Recall:0.8050 F1:0.7547 AUPR:0.7905
# Epoch:34 Train_loss:4.2908 ACC:0.7375 AUROC:0.8130 Precision:0.7084 Recall:0.8073 F1:0.7546 AUPR:0.7884
# Epoch:35 Train_loss:4.2851 ACC:0.7388 AUROC:0.8139 Precision:0.7098 Recall:0.8079 F1:0.7557 AUPR:0.7897
# Epoch:35 Val_loss:4.1721 ACC:0.7530 AUROC:0.8283 Precision:0.7394 Recall:0.7806 F1:0.7594 AUPR:0.8043
# ==> Saving model...
# Epoch:36 Train_loss:4.3067 ACC:0.7358 AUROC:0.8106 Precision:0.7063 Recall:0.8071 F1:0.7534 AUPR:0.7857
# Epoch:37 Train_loss:4.2658 ACC:0.7412 AUROC:0.8159 Precision:0.7125 Recall:0.8088 F1:0.7576 AUPR:0.7918
# Epoch:38 Train_loss:4.2784 ACC:0.7401 AUROC:0.8147 Precision:0.7112 Recall:0.8085 F1:0.7567 AUPR:0.7901
# Epoch:39 Train_loss:4.2578 ACC:0.7429 AUROC:0.8168 Precision:0.7144 Recall:0.8096 F1:0.7590 AUPR:0.7916
# Epoch:40 Train_loss:4.2403 ACC:0.7433 AUROC:0.8193 Precision:0.7145 Recall:0.8104 F1:0.7594 AUPR:0.7952
# Epoch:40 Val_loss:4.1207 ACC:0.7623 AUROC:0.8324 Precision:0.7376 Recall:0.8148 F1:0.7743 AUPR:0.8085
# ==> Saving model...
# ==> Saving model...
# Epoch:41 Train_loss:4.2559 ACC:0.7413 AUROC:0.8169 Precision:0.7128 Recall:0.8082 F1:0.7575 AUPR:0.7927
# Epoch:42 Train_loss:4.2514 ACC:0.7415 AUROC:0.8174 Precision:0.7120 Recall:0.8112 F1:0.7584 AUPR:0.7919
# Epoch:43 Train_loss:4.2590 ACC:0.7418 AUROC:0.8169 Precision:0.7130 Recall:0.8094 F1:0.7581 AUPR:0.7930
# Epoch:44 Train_loss:4.2423 ACC:0.7428 AUROC:0.8184 Precision:0.7136 Recall:0.8112 F1:0.7592 AUPR:0.7945
# Epoch:45 Train_loss:4.2595 ACC:0.7420 AUROC:0.8167 Precision:0.7129 Recall:0.8104 F1:0.7585 AUPR:0.7928
# Epoch:45 Val_loss:4.2179 ACC:0.7465 AUROC:0.8217 Precision:0.7174 Recall:0.8139 F1:0.7626 AUPR:0.8022
# Epoch:46 Train_loss:4.2765 ACC:0.7392 AUROC:0.8151 Precision:0.7099 Recall:0.8088 F1:0.7562 AUPR:0.7914
# Epoch:47 Train_loss:4.2305 ACC:0.7451 AUROC:0.8202 Precision:0.7167 Recall:0.8106 F1:0.7607 AUPR:0.7957
# Epoch:48 Train_loss:4.2365 ACC:0.7429 AUROC:0.8198 Precision:0.7145 Recall:0.8092 F1:0.7589 AUPR:0.7971
# Epoch:49 Train_loss:4.2281 ACC:0.7447 AUROC:0.8205 Precision:0.7149 Recall:0.8141 F1:0.7613 AUPR:0.7968
# Epoch:50 Train_loss:4.2044 ACC:0.7475 AUROC:0.8230 Precision:0.7188 Recall:0.8131 F1:0.7631 AUPR:0.7984
# Epoch:50 Val_loss:4.1717 ACC:0.7539 AUROC:0.8359 Precision:0.7680 Recall:0.7274 F1:0.7471 AUPR:0.8146
# ==> Saving model...
# ==> Saving model...
# Epoch:51 Train_loss:4.2275 ACC:0.7458 AUROC:0.8205 Precision:0.7168 Recall:0.8125 F1:0.7617 AUPR:0.7967
# Epoch:52 Train_loss:4.2585 ACC:0.7407 AUROC:0.8171 Precision:0.7110 Recall:0.8109 F1:0.7577 AUPR:0.7947
# Epoch:53 Train_loss:4.2696 ACC:0.7385 AUROC:0.8153 Precision:0.7098 Recall:0.8068 F1:0.7552 AUPR:0.7919
# Epoch:54 Train_loss:4.2006 ACC:0.7465 AUROC:0.8236 Precision:0.7188 Recall:0.8100 F1:0.7617 AUPR:0.8011
# Epoch:55 Train_loss:4.1950 ACC:0.7466 AUROC:0.8245 Precision:0.7186 Recall:0.8109 F1:0.7619 AUPR:0.8023
# Epoch:55 Val_loss:4.0482 ACC:0.7637 AUROC:0.8410 Precision:0.7511 Recall:0.7884 F1:0.7693 AUPR:0.8234
# ==> Saving model...
# Epoch:56 Train_loss:4.1830 ACC:0.7484 AUROC:0.8252 Precision:0.7209 Recall:0.8107 F1:0.7632 AUPR:0.8019
# Epoch:57 Train_loss:4.1663 ACC:0.7511 AUROC:0.8277 Precision:0.7225 Recall:0.8154 F1:0.7661 AUPR:0.8056
# Epoch:58 Train_loss:4.1759 ACC:0.7492 AUROC:0.8267 Precision:0.7223 Recall:0.8098 F1:0.7635 AUPR:0.8051
# Epoch:59 Train_loss:4.2278 ACC:0.7435 AUROC:0.8207 Precision:0.7148 Recall:0.8102 F1:0.7595 AUPR:0.7982
# Epoch:60 Train_loss:4.2503 ACC:0.7395 AUROC:0.8176 Precision:0.7103 Recall:0.8089 F1:0.7564 AUPR:0.7962
# Epoch:60 Val_loss:4.0936 ACC:0.7563 AUROC:0.8357 Precision:0.7274 Recall:0.8197 F1:0.7708 AUPR:0.8178
# ==> Saving model...
# Epoch:61 Train_loss:4.2377 ACC:0.7439 AUROC:0.8196 Precision:0.7161 Recall:0.8083 F1:0.7594 AUPR:0.7966
# Epoch:62 Train_loss:4.2350 ACC:0.7428 AUROC:0.8192 Precision:0.7139 Recall:0.8104 F1:0.7591 AUPR:0.7953
# Epoch:63 Train_loss:4.2277 ACC:0.7430 AUROC:0.8207 Precision:0.7154 Recall:0.8070 F1:0.7585 AUPR:0.7996
# Epoch:64 Train_loss:4.2303 ACC:0.7422 AUROC:0.8203 Precision:0.7135 Recall:0.8095 F1:0.7585 AUPR:0.7987
# Epoch:65 Train_loss:4.2083 ACC:0.7451 AUROC:0.8229 Precision:0.7169 Recall:0.8103 F1:0.7607 AUPR:0.8012
# Epoch:65 Val_loss:4.1330 ACC:0.7535 AUROC:0.8318 Precision:0.7235 Recall:0.8200 F1:0.7688 AUPR:0.8117
# Epoch:66 Train_loss:4.2310 ACC:0.7417 AUROC:0.8200 Precision:0.7135 Recall:0.8079 F1:0.7578 AUPR:0.7986
# Epoch:67 Train_loss:4.2240 ACC:0.7429 AUROC:0.8208 Precision:0.7143 Recall:0.8096 F1:0.7590 AUPR:0.7986
# Epoch:68 Train_loss:4.2234 ACC:0.7451 AUROC:0.8207 Precision:0.7152 Recall:0.8147 F1:0.7617 AUPR:0.7980
# Epoch:69 Train_loss:4.2244 ACC:0.7432 AUROC:0.8211 Precision:0.7140 Recall:0.8112 F1:0.7595 AUPR:0.7993
# Epoch:70 Train_loss:4.2199 ACC:0.7444 AUROC:0.8213 Precision:0.7159 Recall:0.8105 F1:0.7603 AUPR:0.7998
# Epoch:70 Val_loss:4.0974 ACC:0.7540 AUROC:0.8351 Precision:0.7213 Recall:0.8283 F1:0.7711 AUPR:0.8158
# ==> Saving model...
# Epoch:71 Train_loss:4.2357 ACC:0.7425 AUROC:0.8193 Precision:0.7139 Recall:0.8095 F1:0.7587 AUPR:0.7983
# Epoch:72 Train_loss:4.2291 ACC:0.7427 AUROC:0.8207 Precision:0.7140 Recall:0.8098 F1:0.7589 AUPR:0.7984
# Epoch:73 Train_loss:4.1989 ACC:0.7454 AUROC:0.8236 Precision:0.7169 Recall:0.8109 F1:0.7610 AUPR:0.8031
# Epoch:74 Train_loss:4.2011 ACC:0.7447 AUROC:0.8235 Precision:0.7170 Recall:0.8085 F1:0.7600 AUPR:0.8038
# Epoch:75 Train_loss:4.2076 ACC:0.7445 AUROC:0.8221 Precision:0.7156 Recall:0.8115 F1:0.7605 AUPR:0.8009
# Epoch:75 Val_loss:4.1010 ACC:0.7538 AUROC:0.8353 Precision:0.7172 Recall:0.8386 F1:0.7731 AUPR:0.8147
# Epoch:76 Train_loss:4.1959 ACC:0.7454 AUROC:0.8242 Precision:0.7172 Recall:0.8105 F1:0.7610 AUPR:0.8032
# Epoch:77 Train_loss:4.1861 ACC:0.7474 AUROC:0.8253 Precision:0.7189 Recall:0.8124 F1:0.7628 AUPR:0.8037
# Epoch:78 Train_loss:4.1971 ACC:0.7456 AUROC:0.8241 Precision:0.7168 Recall:0.8120 F1:0.7614 AUPR:0.8042
# Epoch:79 Train_loss:4.1938 ACC:0.7458 AUROC:0.8242 Precision:0.7177 Recall:0.8104 F1:0.7612 AUPR:0.8035
# Epoch:80 Train_loss:4.1739 ACC:0.7480 AUROC:0.8265 Precision:0.7197 Recall:0.8122 F1:0.7632 AUPR:0.8063
# Epoch:80 Val_loss:4.0725 ACC:0.7563 AUROC:0.8404 Precision:0.7106 Recall:0.8642 F1:0.7799 AUPR:0.8202
# ==> Saving model...
# Epoch:81 Train_loss:4.1868 ACC:0.7461 AUROC:0.8248 Precision:0.7180 Recall:0.8105 F1:0.7615 AUPR:0.8048
# Epoch:82 Train_loss:4.1917 ACC:0.7448 AUROC:0.8246 Precision:0.7176 Recall:0.8075 F1:0.7599 AUPR:0.8046
# Epoch:83 Train_loss:4.1839 ACC:0.7479 AUROC:0.8253 Precision:0.7197 Recall:0.8121 F1:0.7631 AUPR:0.8031
# Epoch:84 Train_loss:4.1684 ACC:0.7484 AUROC:0.8273 Precision:0.7205 Recall:0.8117 F1:0.7634 AUPR:0.8057
# Epoch:85 Train_loss:4.1774 ACC:0.7489 AUROC:0.8261 Precision:0.7208 Recall:0.8127 F1:0.7640 AUPR:0.8047
# Epoch:85 Val_loss:4.0622 ACC:0.7576 AUROC:0.8389 Precision:0.7337 Recall:0.8088 F1:0.7694 AUPR:0.8194
# Epoch:86 Train_loss:4.1562 ACC:0.7499 AUROC:0.8285 Precision:0.7222 Recall:0.8124 F1:0.7646 AUPR:0.8078
# Epoch:87 Train_loss:4.1619 ACC:0.7489 AUROC:0.8279 Precision:0.7214 Recall:0.8110 F1:0.7636 AUPR:0.8084
# Epoch:88 Train_loss:4.1684 ACC:0.7476 AUROC:0.8268 Precision:0.7195 Recall:0.8116 F1:0.7628 AUPR:0.8069
# Epoch:89 Train_loss:4.1459 ACC:0.7511 AUROC:0.8298 Precision:0.7235 Recall:0.8129 F1:0.7656 AUPR:0.8093
# Epoch:90 Train_loss:4.1356 ACC:0.7522 AUROC:0.8307 Precision:0.7243 Recall:0.8143 F1:0.7667 AUPR:0.8097
# Epoch:90 Val_loss:4.0375 ACC:0.7610 AUROC:0.8410 Precision:0.7374 Recall:0.8111 F1:0.7725 AUPR:0.8198
# ==> Saving model...
# Epoch:91 Train_loss:4.1481 ACC:0.7516 AUROC:0.8294 Precision:0.7236 Recall:0.8142 F1:0.7662 AUPR:0.8087
# Epoch:92 Train_loss:4.1514 ACC:0.7508 AUROC:0.8288 Precision:0.7227 Recall:0.8140 F1:0.7656 AUPR:0.8084
# Epoch:93 Train_loss:4.1347 ACC:0.7532 AUROC:0.8307 Precision:0.7254 Recall:0.8150 F1:0.7676 AUPR:0.8101
# Epoch:94 Train_loss:4.1554 ACC:0.7501 AUROC:0.8286 Precision:0.7216 Recall:0.8145 F1:0.7652 AUPR:0.8078
# Epoch:95 Train_loss:4.1608 ACC:0.7506 AUROC:0.8278 Precision:0.7225 Recall:0.8137 F1:0.7654 AUPR:0.8075
# Epoch:95 Val_loss:4.0231 ACC:0.7621 AUROC:0.8422 Precision:0.7408 Recall:0.8064 F1:0.7722 AUPR:0.8205
# ==> Saving model...
# Epoch:96 Train_loss:4.1538 ACC:0.7518 AUROC:0.8286 Precision:0.7231 Recall:0.8162 F1:0.7668 AUPR:0.8069
# Epoch:97 Train_loss:4.1596 ACC:0.7496 AUROC:0.8276 Precision:0.7211 Recall:0.8140 F1:0.7648 AUPR:0.8066
# Epoch:98 Train_loss:4.1413 ACC:0.7532 AUROC:0.8301 Precision:0.7245 Recall:0.8171 F1:0.7680 AUPR:0.8089
# Epoch:99 Train_loss:4.1399 ACC:0.7532 AUROC:0.8295 Precision:0.7243 Recall:0.8178 F1:0.7682 AUPR:0.8079
# Epoch:100 Train_loss:4.1422 ACC:0.7508 AUROC:0.8297 Precision:0.7221 Recall:0.8156 F1:0.7660 AUPR:0.8095
# Epoch:100 Val_loss:4.0141 ACC:0.7634 AUROC:0.8429 Precision:0.7363 Recall:0.8202 F1:0.7759 AUPR:0.8203
# ==> Saving model...
# ==> Saving model...
# Epoch:101 Train_loss:4.1406 ACC:0.7517 AUROC:0.8298 Precision:0.7220 Recall:0.8187 F1:0.7673 AUPR:0.8086
# Epoch:102 Train_loss:4.1308 ACC:0.7524 AUROC:0.8313 Precision:0.7249 Recall:0.8135 F1:0.7667 AUPR:0.8113
# Epoch:103 Train_loss:4.1153 ACC:0.7540 AUROC:0.8322 Precision:0.7250 Recall:0.8185 F1:0.7689 AUPR:0.8112
# Epoch:104 Train_loss:4.1317 ACC:0.7525 AUROC:0.8309 Precision:0.7237 Recall:0.8168 F1:0.7674 AUPR:0.8103
# Epoch:105 Train_loss:4.1201 ACC:0.7529 AUROC:0.8324 Precision:0.7245 Recall:0.8163 F1:0.7677 AUPR:0.8125
# Epoch:105 Val_loss:3.9819 ACC:0.7649 AUROC:0.8473 Precision:0.7276 Recall:0.8466 F1:0.7826 AUPR:0.8270
# ==> Saving model...
# Epoch:106 Train_loss:4.1295 ACC:0.7540 AUROC:0.8312 Precision:0.7257 Recall:0.8165 F1:0.7685 AUPR:0.8099
# Epoch:107 Train_loss:4.1231 ACC:0.7525 AUROC:0.8320 Precision:0.7246 Recall:0.8146 F1:0.7670 AUPR:0.8119
# Epoch:108 Train_loss:4.1088 ACC:0.7555 AUROC:0.8336 Precision:0.7283 Recall:0.8152 F1:0.7693 AUPR:0.8132
# Epoch:109 Train_loss:4.1243 ACC:0.7537 AUROC:0.8320 Precision:0.7260 Recall:0.8151 F1:0.7680 AUPR:0.8115
# Epoch:110 Train_loss:4.1049 ACC:0.7558 AUROC:0.8345 Precision:0.7278 Recall:0.8175 F1:0.7700 AUPR:0.8150
# Epoch:110 Val_loss:3.9930 ACC:0.7678 AUROC:0.8462 Precision:0.7442 Recall:0.8160 F1:0.7784 AUPR:0.8245
# ==> Saving model...
# Epoch:111 Train_loss:4.1049 ACC:0.7548 AUROC:0.8335 Precision:0.7269 Recall:0.8164 F1:0.7690 AUPR:0.8114
# Epoch:112 Train_loss:4.1171 ACC:0.7544 AUROC:0.8326 Precision:0.7266 Recall:0.8157 F1:0.7685 AUPR:0.8129
# Epoch:113 Train_loss:4.1042 ACC:0.7545 AUROC:0.8342 Precision:0.7275 Recall:0.8138 F1:0.7682 AUPR:0.8148
# Epoch:114 Train_loss:4.1089 ACC:0.7556 AUROC:0.8340 Precision:0.7277 Recall:0.8167 F1:0.7697 AUPR:0.8147
# Epoch:115 Train_loss:4.1095 ACC:0.7554 AUROC:0.8336 Precision:0.7277 Recall:0.8163 F1:0.7694 AUPR:0.8130
# Epoch:115 Val_loss:3.9942 ACC:0.7688 AUROC:0.8463 Precision:0.7331 Recall:0.8458 F1:0.7854 AUPR:0.8250
# Epoch:116 Train_loss:4.1163 ACC:0.7532 AUROC:0.8329 Precision:0.7252 Recall:0.8154 F1:0.7676 AUPR:0.8125
# Epoch:117 Train_loss:4.1074 ACC:0.7554 AUROC:0.8335 Precision:0.7284 Recall:0.8146 F1:0.7691 AUPR:0.8125
# Epoch:118 Train_loss:4.1069 ACC:0.7546 AUROC:0.8337 Precision:0.7261 Recall:0.8177 F1:0.7692 AUPR:0.8128
# Epoch:119 Train_loss:4.1027 ACC:0.7552 AUROC:0.8343 Precision:0.7275 Recall:0.8161 F1:0.7693 AUPR:0.8154
# Epoch:120 Train_loss:4.1091 ACC:0.7546 AUROC:0.8333 Precision:0.7276 Recall:0.8138 F1:0.7683 AUPR:0.8142
# Epoch:120 Val_loss:3.9675 ACC:0.7709 AUROC:0.8483 Precision:0.7430 Recall:0.8279 F1:0.7832 AUPR:0.8262
# ==> Saving model...
# ==> Saving model...
# Epoch:121 Train_loss:4.0963 ACC:0.7566 AUROC:0.8347 Precision:0.7285 Recall:0.8182 F1:0.7708 AUPR:0.8148
# Epoch:122 Train_loss:4.0944 ACC:0.7573 AUROC:0.8350 Precision:0.7297 Recall:0.8174 F1:0.7710 AUPR:0.8147
# Epoch:123 Train_loss:4.0987 ACC:0.7562 AUROC:0.8344 Precision:0.7276 Recall:0.8191 F1:0.7706 AUPR:0.8133
# Epoch:124 Train_loss:4.0834 ACC:0.7581 AUROC:0.8363 Precision:0.7304 Recall:0.8183 F1:0.7719 AUPR:0.8168
# Epoch:125 Train_loss:4.0868 ACC:0.7573 AUROC:0.8358 Precision:0.7294 Recall:0.8181 F1:0.7712 AUPR:0.8169
# Epoch:125 Val_loss:3.9656 ACC:0.7667 AUROC:0.8489 Precision:0.7446 Recall:0.8115 F1:0.7767 AUPR:0.8285
# ==> Saving model...
# Epoch:126 Train_loss:4.0807 ACC:0.7567 AUROC:0.8368 Precision:0.7296 Recall:0.8156 F1:0.7702 AUPR:0.8178
# Epoch:127 Train_loss:4.0734 ACC:0.7589 AUROC:0.8375 Precision:0.7314 Recall:0.8184 F1:0.7724 AUPR:0.8175
# Epoch:128 Train_loss:4.0775 ACC:0.7584 AUROC:0.8370 Precision:0.7310 Recall:0.8176 F1:0.7719 AUPR:0.8175
# Epoch:129 Train_loss:4.0886 ACC:0.7553 AUROC:0.8354 Precision:0.7275 Recall:0.8162 F1:0.7693 AUPR:0.8156
# Epoch:130 Train_loss:4.0771 ACC:0.7582 AUROC:0.8372 Precision:0.7316 Recall:0.8155 F1:0.7713 AUPR:0.8181
# Epoch:130 Val_loss:3.9485 ACC:0.7712 AUROC:0.8506 Precision:0.7522 Recall:0.8090 F1:0.7796 AUPR:0.8280
# ==> Saving model...
# ==> Saving model...
# Epoch:131 Train_loss:4.0801 ACC:0.7594 AUROC:0.8367 Precision:0.7312 Recall:0.8204 F1:0.7732 AUPR:0.8169
# Epoch:132 Train_loss:4.0808 ACC:0.7583 AUROC:0.8368 Precision:0.7308 Recall:0.8179 F1:0.7719 AUPR:0.8175
# Epoch:133 Train_loss:4.0657 ACC:0.7590 AUROC:0.8377 Precision:0.7313 Recall:0.8188 F1:0.7726 AUPR:0.8179
# Epoch:134 Train_loss:4.0905 ACC:0.7568 AUROC:0.8355 Precision:0.7290 Recall:0.8175 F1:0.7707 AUPR:0.8154
# Epoch:135 Train_loss:4.0767 ACC:0.7572 AUROC:0.8369 Precision:0.7293 Recall:0.8180 F1:0.7711 AUPR:0.8172
# Epoch:135 Val_loss:3.9713 ACC:0.7691 AUROC:0.8498 Precision:0.7594 Recall:0.7884 F1:0.7736 AUPR:0.8290
# Epoch:136 Train_loss:4.0725 ACC:0.7585 AUROC:0.8378 Precision:0.7314 Recall:0.8172 F1:0.7719 AUPR:0.8181
# Epoch:137 Train_loss:4.0715 ACC:0.7591 AUROC:0.8374 Precision:0.7318 Recall:0.8179 F1:0.7724 AUPR:0.8176
# Epoch:138 Train_loss:4.0758 ACC:0.7575 AUROC:0.8373 Precision:0.7300 Recall:0.8175 F1:0.7713 AUPR:0.8175
# Epoch:139 Train_loss:4.0735 ACC:0.7587 AUROC:0.8375 Precision:0.7310 Recall:0.8186 F1:0.7723 AUPR:0.8173
# Epoch:140 Train_loss:4.0802 ACC:0.7579 AUROC:0.8367 Precision:0.7302 Recall:0.8181 F1:0.7716 AUPR:0.8168
# Epoch:140 Val_loss:3.9796 ACC:0.7692 AUROC:0.8469 Precision:0.7441 Recall:0.8211 F1:0.7807 AUPR:0.8254
# ==> Saving model...
# Epoch:141 Train_loss:4.0665 ACC:0.7600 AUROC:0.8382 Precision:0.7331 Recall:0.8175 F1:0.7730 AUPR:0.8200
# Epoch:142 Train_loss:4.0534 ACC:0.7600 AUROC:0.8395 Precision:0.7330 Recall:0.8178 F1:0.7731 AUPR:0.8202
# Epoch:143 Train_loss:4.0604 ACC:0.7597 AUROC:0.8390 Precision:0.7320 Recall:0.8193 F1:0.7732 AUPR:0.8202
# Epoch:144 Train_loss:4.0543 ACC:0.7603 AUROC:0.8396 Precision:0.7325 Recall:0.8202 F1:0.7739 AUPR:0.8197
# Epoch:145 Train_loss:4.0646 ACC:0.7580 AUROC:0.8384 Precision:0.7309 Recall:0.8169 F1:0.7715 AUPR:0.8194
# Epoch:145 Val_loss:3.9610 ACC:0.7728 AUROC:0.8491 Precision:0.7457 Recall:0.8277 F1:0.7846 AUPR:0.8273
# Epoch:146 Train_loss:4.0785 ACC:0.7588 AUROC:0.8371 Precision:0.7317 Recall:0.8173 F1:0.7721 AUPR:0.8176
# Epoch:147 Train_loss:4.0622 ACC:0.7602 AUROC:0.8385 Precision:0.7329 Recall:0.8189 F1:0.7735 AUPR:0.8186
# Epoch:148 Train_loss:4.0834 ACC:0.7572 AUROC:0.8367 Precision:0.7294 Recall:0.8178 F1:0.7711 AUPR:0.8168
# Epoch:149 Train_loss:4.1082 ACC:0.7565 AUROC:0.8333 Precision:0.7265 Recall:0.8226 F1:0.7716 AUPR:0.8094
# Epoch:150 Train_loss:4.0860 ACC:0.7577 AUROC:0.8357 Precision:0.7289 Recall:0.8208 F1:0.7721 AUPR:0.8158
# Epoch:150 Val_loss:3.9633 ACC:0.7724 AUROC:0.8485 Precision:0.7527 Recall:0.8111 F1:0.7808 AUPR:0.8245
# ==> Saving model...
# Epoch:151 Train_loss:4.0859 ACC:0.7581 AUROC:0.8358 Precision:0.7304 Recall:0.8183 F1:0.7718 AUPR:0.8142
# Epoch:152 Train_loss:4.0846 ACC:0.7575 AUROC:0.8361 Precision:0.7295 Recall:0.8187 F1:0.7715 AUPR:0.8159
# Epoch:153 Train_loss:4.0691 ACC:0.7592 AUROC:0.8379 Precision:0.7316 Recall:0.8189 F1:0.7728 AUPR:0.8178
# Epoch:154 Train_loss:4.0881 ACC:0.7569 AUROC:0.8355 Precision:0.7289 Recall:0.8178 F1:0.7708 AUPR:0.8161
# Epoch:155 Train_loss:4.1121 ACC:0.7548 AUROC:0.8330 Precision:0.7257 Recall:0.8192 F1:0.7696 AUPR:0.8114
# Epoch:155 Val_loss:3.9981 ACC:0.7710 AUROC:0.8437 Precision:0.7398 Recall:0.8364 F1:0.7851 AUPR:0.8180
# Epoch:156 Train_loss:4.0923 ACC:0.7585 AUROC:0.8347 Precision:0.7295 Recall:0.8217 F1:0.7728 AUPR:0.8126
# Epoch:157 Train_loss:4.0992 ACC:0.7567 AUROC:0.8343 Precision:0.7276 Recall:0.8204 F1:0.7713 AUPR:0.8129
# Epoch:158 Train_loss:4.1065 ACC:0.7569 AUROC:0.8339 Precision:0.7279 Recall:0.8208 F1:0.7715 AUPR:0.8129
# Epoch:159 Train_loss:4.1181 ACC:0.7537 AUROC:0.8319 Precision:0.7246 Recall:0.8183 F1:0.7686 AUPR:0.8106
# Epoch:160 Train_loss:4.1127 ACC:0.7573 AUROC:0.8329 Precision:0.7275 Recall:0.8227 F1:0.7722 AUPR:0.8099
# Epoch:160 Val_loss:3.9865 ACC:0.7665 AUROC:0.8457 Precision:0.7312 Recall:0.8434 F1:0.7833 AUPR:0.8228
# ==> Saving model...
# Epoch:161 Train_loss:4.1030 ACC:0.7574 AUROC:0.8341 Precision:0.7282 Recall:0.8216 F1:0.7720 AUPR:0.8115
# Epoch:162 Train_loss:4.1080 ACC:0.7572 AUROC:0.8330 Precision:0.7273 Recall:0.8229 F1:0.7721 AUPR:0.8107
# Epoch:163 Train_loss:4.1079 ACC:0.7577 AUROC:0.8334 Precision:0.7291 Recall:0.8201 F1:0.7719 AUPR:0.8109
# Epoch:164 Train_loss:4.0880 ACC:0.7586 AUROC:0.8357 Precision:0.7299 Recall:0.8210 F1:0.7728 AUPR:0.8142
# Epoch:165 Train_loss:4.0916 ACC:0.7582 AUROC:0.8356 Precision:0.7300 Recall:0.8194 F1:0.7721 AUPR:0.8148
# Epoch:165 Val_loss:4.0270 ACC:0.7685 AUROC:0.8425 Precision:0.7437 Recall:0.8193 F1:0.7797 AUPR:0.8179
# Epoch:166 Train_loss:4.0788 ACC:0.7583 AUROC:0.8368 Precision:0.7298 Recall:0.8204 F1:0.7725 AUPR:0.8152
# Epoch:167 Train_loss:4.0758 ACC:0.7589 AUROC:0.8373 Precision:0.7316 Recall:0.8178 F1:0.7723 AUPR:0.8186
# Epoch:168 Train_loss:4.0963 ACC:0.7577 AUROC:0.8349 Precision:0.7289 Recall:0.8205 F1:0.7720 AUPR:0.8141
# Epoch:169 Train_loss:4.0981 ACC:0.7582 AUROC:0.8346 Precision:0.7284 Recall:0.8235 F1:0.7730 AUPR:0.8126
# Epoch:170 Train_loss:4.0695 ACC:0.7593 AUROC:0.8379 Precision:0.7311 Recall:0.8202 F1:0.7731 AUPR:0.8184
# Epoch:170 Val_loss:3.9919 ACC:0.7676 AUROC:0.8468 Precision:0.7521 Recall:0.7986 F1:0.7747 AUPR:0.8253
# ==> Saving model...
# Epoch:171 Train_loss:4.1258 ACC:0.7554 AUROC:0.8314 Precision:0.7271 Recall:0.8178 F1:0.7698 AUPR:0.8091
# Epoch:172 Train_loss:4.1053 ACC:0.7571 AUROC:0.8343 Precision:0.7290 Recall:0.8184 F1:0.7711 AUPR:0.8143
# Epoch:173 Train_loss:4.0567 ACC:0.7615 AUROC:0.8393 Precision:0.7338 Recall:0.8207 F1:0.7748 AUPR:0.8191
# Epoch:174 Train_loss:4.0611 ACC:0.7606 AUROC:0.8391 Precision:0.7338 Recall:0.8180 F1:0.7736 AUPR:0.8200
# Epoch:175 Train_loss:4.0609 ACC:0.7604 AUROC:0.8386 Precision:0.7325 Recall:0.8206 F1:0.7740 AUPR:0.8180
# Epoch:175 Val_loss:3.9641 ACC:0.7731 AUROC:0.8486 Precision:0.7448 Recall:0.8306 F1:0.7853 AUPR:0.8243
# Epoch:176 Train_loss:4.0502 ACC:0.7607 AUROC:0.8395 Precision:0.7337 Recall:0.8185 F1:0.7738 AUPR:0.8191
# Epoch:177 Train_loss:4.0387 ACC:0.7634 AUROC:0.8416 Precision:0.7361 Recall:0.8210 F1:0.7763 AUPR:0.8231
# Epoch:178 Train_loss:4.0904 ACC:0.7573 AUROC:0.8353 Precision:0.7288 Recall:0.8196 F1:0.7715 AUPR:0.8134
# Epoch:179 Train_loss:4.0916 ACC:0.7566 AUROC:0.8357 Precision:0.7289 Recall:0.8172 F1:0.7705 AUPR:0.8154
# Epoch:180 Train_loss:4.0751 ACC:0.7591 AUROC:0.8369 Precision:0.7299 Recall:0.8226 F1:0.7735 AUPR:0.8157
# Epoch:180 Val_loss:4.0153 ACC:0.7687 AUROC:0.8426 Precision:0.7323 Recall:0.8470 F1:0.7855 AUPR:0.8172
# ==> Saving model...
# Epoch:181 Train_loss:4.0847 ACC:0.7580 AUROC:0.8361 Precision:0.7300 Recall:0.8188 F1:0.7719 AUPR:0.8155
# Epoch:182 Train_loss:4.0957 ACC:0.7554 AUROC:0.8349 Precision:0.7272 Recall:0.8177 F1:0.7698 AUPR:0.8137
# Epoch:183 Train_loss:4.0816 ACC:0.7586 AUROC:0.8363 Precision:0.7299 Recall:0.8209 F1:0.7727 AUPR:0.8153
# Epoch:184 Train_loss:4.0834 ACC:0.7568 AUROC:0.8363 Precision:0.7284 Recall:0.8187 F1:0.7710 AUPR:0.8163
# Epoch:185 Train_loss:4.0734 ACC:0.7591 AUROC:0.8372 Precision:0.7309 Recall:0.8200 F1:0.7729 AUPR:0.8163
# Epoch:185 Val_loss:3.9992 ACC:0.7668 AUROC:0.8455 Precision:0.7493 Recall:0.8017 F1:0.7747 AUPR:0.8219
# Epoch:186 Train_loss:4.0963 ACC:0.7564 AUROC:0.8352 Precision:0.7289 Recall:0.8165 F1:0.7702 AUPR:0.8142
# Epoch:187 Train_loss:4.0934 ACC:0.7556 AUROC:0.8354 Precision:0.7280 Recall:0.8162 F1:0.7696 AUPR:0.8145
# Epoch:188 Train_loss:4.0791 ACC:0.7574 AUROC:0.8366 Precision:0.7294 Recall:0.8183 F1:0.7713 AUPR:0.8161
# Epoch:189 Train_loss:4.0843 ACC:0.7581 AUROC:0.8364 Precision:0.7304 Recall:0.8185 F1:0.7719 AUPR:0.8161
# Epoch:190 Train_loss:4.0568 ACC:0.7609 AUROC:0.8388 Precision:0.7326 Recall:0.8218 F1:0.7746 AUPR:0.8187
# Epoch:190 Val_loss:4.0028 ACC:0.7697 AUROC:0.8441 Precision:0.7428 Recall:0.8244 F1:0.7815 AUPR:0.8188
# ==> Saving model...
# Epoch:191 Train_loss:4.0627 ACC:0.7585 AUROC:0.8386 Precision:0.7309 Recall:0.8183 F1:0.7722 AUPR:0.8187
# Epoch:192 Train_loss:4.0603 ACC:0.7603 AUROC:0.8389 Precision:0.7329 Recall:0.8190 F1:0.7736 AUPR:0.8186
# Epoch:193 Train_loss:4.0718 ACC:0.7593 AUROC:0.8375 Precision:0.7313 Recall:0.8196 F1:0.7729 AUPR:0.8178
# Epoch:194 Train_loss:4.0480 ACC:0.7628 AUROC:0.8398 Precision:0.7343 Recall:0.8235 F1:0.7764 AUPR:0.8196
# Epoch:195 Train_loss:4.0555 ACC:0.7597 AUROC:0.8389 Precision:0.7306 Recall:0.8228 F1:0.7740 AUPR:0.8187
# Epoch:195 Val_loss:3.9865 ACC:0.7726 AUROC:0.8465 Precision:0.7511 Recall:0.8153 F1:0.7819 AUPR:0.8227
# Epoch:196 Train_loss:4.0651 ACC:0.7600 AUROC:0.8382 Precision:0.7316 Recall:0.8213 F1:0.7738 AUPR:0.8176
# Epoch:197 Train_loss:4.0832 ACC:0.7597 AUROC:0.8362 Precision:0.7315 Recall:0.8208 F1:0.7735 AUPR:0.8145
# Epoch:198 Train_loss:4.0869 ACC:0.7580 AUROC:0.8358 Precision:0.7293 Recall:0.8205 F1:0.7722 AUPR:0.8150
# Epoch:199 Train_loss:4.0671 ACC:0.7591 AUROC:0.8380 Precision:0.7307 Recall:0.8206 F1:0.7731 AUPR:0.8172
# Epoch:200 Train_loss:4.0438 ACC:0.7625 AUROC:0.8405 Precision:0.7346 Recall:0.8220 F1:0.7758 AUPR:0.8199
# Epoch:200 Val_loss:3.9437 ACC:0.7734 AUROC:0.8509 Precision:0.7406 Recall:0.8416 F1:0.7878 AUPR:0.8277
# ==> Saving model...
# ==> Saving model...
# Epoch:201 Train_loss:4.0641 ACC:0.7611 AUROC:0.8388 Precision:0.7337 Recall:0.8195 F1:0.7743 AUPR:0.8189
# Epoch:202 Train_loss:4.0684 ACC:0.7604 AUROC:0.8377 Precision:0.7313 Recall:0.8233 F1:0.7746 AUPR:0.8156
# Epoch:203 Train_loss:4.0713 ACC:0.7596 AUROC:0.8375 Precision:0.7314 Recall:0.8204 F1:0.7734 AUPR:0.8161
# Epoch:204 Train_loss:4.0676 ACC:0.7587 AUROC:0.8381 Precision:0.7304 Recall:0.8202 F1:0.7727 AUPR:0.8185
# Epoch:205 Train_loss:4.0805 ACC:0.7581 AUROC:0.8361 Precision:0.7303 Recall:0.8184 F1:0.7718 AUPR:0.8143
# Epoch:205 Val_loss:4.0139 ACC:0.7699 AUROC:0.8434 Precision:0.7419 Recall:0.8275 F1:0.7823 AUPR:0.8186
# Epoch:206 Train_loss:4.0818 ACC:0.7589 AUROC:0.8365 Precision:0.7304 Recall:0.8208 F1:0.7730 AUPR:0.8161
# Epoch:207 Train_loss:4.0776 ACC:0.7585 AUROC:0.8369 Precision:0.7297 Recall:0.8212 F1:0.7728 AUPR:0.8165
# Epoch:208 Train_loss:4.0623 ACC:0.7603 AUROC:0.8389 Precision:0.7327 Recall:0.8196 F1:0.7737 AUPR:0.8190
# Epoch:209 Train_loss:4.0573 ACC:0.7609 AUROC:0.8390 Precision:0.7321 Recall:0.8230 F1:0.7749 AUPR:0.8173
# Epoch:210 Train_loss:4.0699 ACC:0.7603 AUROC:0.8374 Precision:0.7317 Recall:0.8219 F1:0.7742 AUPR:0.8161
# Epoch:210 Val_loss:3.9945 ACC:0.7707 AUROC:0.8464 Precision:0.7544 Recall:0.8021 F1:0.7775 AUPR:0.8221
# ==> Saving model...
# Epoch:211 Train_loss:4.0611 ACC:0.7610 AUROC:0.8383 Precision:0.7322 Recall:0.8230 F1:0.7749 AUPR:0.8170
# Epoch:212 Train_loss:4.0491 ACC:0.7618 AUROC:0.8396 Precision:0.7336 Recall:0.8222 F1:0.7754 AUPR:0.8185
# Epoch:213 Train_loss:4.0525 ACC:0.7618 AUROC:0.8394 Precision:0.7334 Recall:0.8226 F1:0.7754 AUPR:0.8191
# Epoch:214 Train_loss:4.0561 ACC:0.7605 AUROC:0.8392 Precision:0.7325 Recall:0.8208 F1:0.7741 AUPR:0.8189
# Epoch:215 Train_loss:4.0522 ACC:0.7622 AUROC:0.8395 Precision:0.7342 Recall:0.8220 F1:0.7756 AUPR:0.8192
# Epoch:215 Val_loss:3.9669 ACC:0.7721 AUROC:0.8475 Precision:0.7405 Recall:0.8379 F1:0.7862 AUPR:0.8215
# Epoch:216 Train_loss:4.0600 ACC:0.7611 AUROC:0.8387 Precision:0.7327 Recall:0.8223 F1:0.7749 AUPR:0.8178
# Epoch:217 Train_loss:4.0784 ACC:0.7600 AUROC:0.8364 Precision:0.7313 Recall:0.8220 F1:0.7740 AUPR:0.8145
# Epoch:218 Train_loss:4.0739 ACC:0.7597 AUROC:0.8370 Precision:0.7310 Recall:0.8217 F1:0.7737 AUPR:0.8145
# Epoch:219 Train_loss:4.0588 ACC:0.7616 AUROC:0.8393 Precision:0.7336 Recall:0.8216 F1:0.7751 AUPR:0.8192
# Epoch:220 Train_loss:4.0626 ACC:0.7606 AUROC:0.8385 Precision:0.7333 Recall:0.8192 F1:0.7739 AUPR:0.8189
# Epoch:220 Val_loss:3.9540 ACC:0.7755 AUROC:0.8499 Precision:0.7492 Recall:0.8280 F1:0.7866 AUPR:0.8279
# ==> Saving model...
# Epoch:221 Train_loss:4.0778 ACC:0.7579 AUROC:0.8369 Precision:0.7311 Recall:0.8159 F1:0.7712 AUPR:0.8164
# Epoch:222 Train_loss:4.0909 ACC:0.7570 AUROC:0.8359 Precision:0.7291 Recall:0.8179 F1:0.7710 AUPR:0.8154
# Epoch:223 Train_loss:4.0881 ACC:0.7580 AUROC:0.8361 Precision:0.7300 Recall:0.8186 F1:0.7718 AUPR:0.8160
# Epoch:224 Train_loss:4.0904 ACC:0.7571 AUROC:0.8358 Precision:0.7306 Recall:0.8146 F1:0.7703 AUPR:0.8163
# Epoch:225 Train_loss:4.0644 ACC:0.7588 AUROC:0.8382 Precision:0.7318 Recall:0.8168 F1:0.7720 AUPR:0.8179
# Epoch:225 Val_loss:3.9768 ACC:0.7712 AUROC:0.8488 Precision:0.7475 Recall:0.8184 F1:0.7813 AUPR:0.8281
# Epoch:226 Train_loss:4.0527 ACC:0.7616 AUROC:0.8399 Precision:0.7343 Recall:0.8200 F1:0.7748 AUPR:0.8193
# Epoch:227 Train_loss:4.0432 ACC:0.7614 AUROC:0.8408 Precision:0.7354 Recall:0.8166 F1:0.7739 AUPR:0.8226
# Epoch:228 Train_loss:4.0491 ACC:0.7622 AUROC:0.8401 Precision:0.7350 Recall:0.8201 F1:0.7752 AUPR:0.8203
# Epoch:229 Train_loss:4.0536 ACC:0.7591 AUROC:0.8396 Precision:0.7320 Recall:0.8176 F1:0.7724 AUPR:0.8207
# Epoch:230 Train_loss:4.0386 ACC:0.7619 AUROC:0.8414 Precision:0.7351 Recall:0.8188 F1:0.7747 AUPR:0.8230
# Epoch:230 Val_loss:3.9552 ACC:0.7734 AUROC:0.8495 Precision:0.7466 Recall:0.8281 F1:0.7852 AUPR:0.8274
# ==> Saving model...
# Epoch:231 Train_loss:4.0525 ACC:0.7612 AUROC:0.8394 Precision:0.7351 Recall:0.8167 F1:0.7737 AUPR:0.8190
# Epoch:232 Train_loss:4.0747 ACC:0.7592 AUROC:0.8372 Precision:0.7310 Recall:0.8202 F1:0.7730 AUPR:0.8163
# Epoch:233 Train_loss:4.0879 ACC:0.7568 AUROC:0.8351 Precision:0.7287 Recall:0.8182 F1:0.7708 AUPR:0.8135
# Epoch:234 Train_loss:4.0860 ACC:0.7582 AUROC:0.8362 Precision:0.7299 Recall:0.8199 F1:0.7723 AUPR:0.8151
# Epoch:235 Train_loss:4.0733 ACC:0.7604 AUROC:0.8370 Precision:0.7321 Recall:0.8213 F1:0.7742 AUPR:0.8159
# Epoch:235 Val_loss:4.0028 ACC:0.7711 AUROC:0.8448 Precision:0.7345 Recall:0.8487 F1:0.7875 AUPR:0.8206
# Epoch:236 Train_loss:4.0744 ACC:0.7582 AUROC:0.8372 Precision:0.7298 Recall:0.8201 F1:0.7723 AUPR:0.8167
# Epoch:237 Train_loss:4.0839 ACC:0.7595 AUROC:0.8363 Precision:0.7304 Recall:0.8228 F1:0.7738 AUPR:0.8142
# Epoch:238 Train_loss:4.0686 ACC:0.7606 AUROC:0.8375 Precision:0.7318 Recall:0.8227 F1:0.7746 AUPR:0.8164
# Epoch:239 Train_loss:4.0790 ACC:0.7595 AUROC:0.8367 Precision:0.7310 Recall:0.8212 F1:0.7735 AUPR:0.8149
# Epoch:240 Train_loss:4.0634 ACC:0.7612 AUROC:0.8382 Precision:0.7333 Recall:0.8211 F1:0.7747 AUPR:0.8173
# Epoch:240 Val_loss:3.9841 ACC:0.7728 AUROC:0.8465 Precision:0.7525 Recall:0.8126 F1:0.7814 AUPR:0.8208
# ==> Saving model...
# Epoch:241 Train_loss:4.0643 ACC:0.7596 AUROC:0.8382 Precision:0.7322 Recall:0.8186 F1:0.7730 AUPR:0.8171
# Epoch:242 Train_loss:4.0657 ACC:0.7602 AUROC:0.8384 Precision:0.7325 Recall:0.8196 F1:0.7736 AUPR:0.8175
# Epoch:243 Train_loss:4.0615 ACC:0.7599 AUROC:0.8385 Precision:0.7321 Recall:0.8197 F1:0.7734 AUPR:0.8181
# Epoch:244 Train_loss:4.0537 ACC:0.7611 AUROC:0.8393 Precision:0.7327 Recall:0.8219 F1:0.7748 AUPR:0.8190
# Epoch:245 Train_loss:4.0491 ACC:0.7611 AUROC:0.8402 Precision:0.7333 Recall:0.8207 F1:0.7746 AUPR:0.8191
# Epoch:245 Val_loss:3.9589 ACC:0.7737 AUROC:0.8489 Precision:0.7454 Recall:0.8313 F1:0.7860 AUPR:0.8243
# Epoch:246 Train_loss:4.0600 ACC:0.7605 AUROC:0.8385 Precision:0.7323 Recall:0.8211 F1:0.7742 AUPR:0.8175
# Epoch:247 Train_loss:4.0986 ACC:0.7579 AUROC:0.8343 Precision:0.7282 Recall:0.8228 F1:0.7727 AUPR:0.8113
# Epoch:248 Train_loss:4.0859 ACC:0.7579 AUROC:0.8354 Precision:0.7288 Recall:0.8216 F1:0.7724 AUPR:0.8121
# Epoch:249 Train_loss:4.0721 ACC:0.7604 AUROC:0.8372 Precision:0.7316 Recall:0.8226 F1:0.7745 AUPR:0.8150
# Epoch:250 Train_loss:4.0740 ACC:0.7580 AUROC:0.8371 Precision:0.7293 Recall:0.8207 F1:0.7723 AUPR:0.8154
# Epoch:250 Val_loss:3.9736 ACC:0.7735 AUROC:0.8473 Precision:0.7451 Recall:0.8315 F1:0.7859 AUPR:0.8218
# ==> Saving model...
# Epoch:251 Train_loss:4.0415 ACC:0.7614 AUROC:0.8407 Precision:0.7337 Recall:0.8208 F1:0.7748 AUPR:0.8202
# Epoch:252 Train_loss:4.0413 ACC:0.7617 AUROC:0.8406 Precision:0.7338 Recall:0.8213 F1:0.7751 AUPR:0.8206
# Epoch:253 Train_loss:4.0503 ACC:0.7622 AUROC:0.8395 Precision:0.7339 Recall:0.8228 F1:0.7758 AUPR:0.8173
# Epoch:254 Train_loss:4.0271 ACC:0.7639 AUROC:0.8420 Precision:0.7359 Recall:0.8232 F1:0.7771 AUPR:0.8214
# Epoch:255 Train_loss:4.0511 ACC:0.7614 AUROC:0.8398 Precision:0.7335 Recall:0.8210 F1:0.7748 AUPR:0.8186
# Epoch:255 Val_loss:3.9700 ACC:0.7740 AUROC:0.8491 Precision:0.7573 Recall:0.8063 F1:0.7811 AUPR:0.8265
# Epoch:256 Train_loss:4.0443 ACC:0.7618 AUROC:0.8404 Precision:0.7344 Recall:0.8203 F1:0.7750 AUPR:0.8199
# Epoch:257 Train_loss:4.0233 ACC:0.7639 AUROC:0.8426 Precision:0.7358 Recall:0.8237 F1:0.7772 AUPR:0.8217
# Epoch:258 Train_loss:4.0361 ACC:0.7624 AUROC:0.8410 Precision:0.7344 Recall:0.8219 F1:0.7757 AUPR:0.8187
# Epoch:259 Train_loss:4.0459 ACC:0.7621 AUROC:0.8402 Precision:0.7338 Recall:0.8228 F1:0.7757 AUPR:0.8204
# Epoch:260 Train_loss:4.0420 ACC:0.7625 AUROC:0.8405 Precision:0.7345 Recall:0.8223 F1:0.7759 AUPR:0.8198
# Epoch:260 Val_loss:3.9604 ACC:0.7711 AUROC:0.8489 Precision:0.7423 Recall:0.8301 F1:0.7838 AUPR:0.8270
# ==> Saving model...
# Epoch:261 Train_loss:4.0363 ACC:0.7631 AUROC:0.8411 Precision:0.7356 Recall:0.8215 F1:0.7762 AUPR:0.8208
# Epoch:262 Train_loss:4.0442 ACC:0.7619 AUROC:0.8403 Precision:0.7341 Recall:0.8212 F1:0.7752 AUPR:0.8195
# Epoch:263 Train_loss:4.0274 ACC:0.7639 AUROC:0.8420 Precision:0.7364 Recall:0.8219 F1:0.7768 AUPR:0.8211
# Epoch:264 Train_loss:4.0270 ACC:0.7624 AUROC:0.8422 Precision:0.7345 Recall:0.8219 F1:0.7758 AUPR:0.8230
# Epoch:265 Train_loss:4.0353 ACC:0.7645 AUROC:0.8414 Precision:0.7368 Recall:0.8232 F1:0.7776 AUPR:0.8212
# Epoch:265 Val_loss:3.9441 ACC:0.7753 AUROC:0.8512 Precision:0.7565 Recall:0.8118 F1:0.7832 AUPR:0.8286
# ==> Saving model...
# Epoch:266 Train_loss:4.0358 ACC:0.7636 AUROC:0.8417 Precision:0.7363 Recall:0.8213 F1:0.7765 AUPR:0.8217
# Epoch:267 Train_loss:4.0408 ACC:0.7636 AUROC:0.8413 Precision:0.7372 Recall:0.8191 F1:0.7760 AUPR:0.8215
# Epoch:268 Train_loss:4.0207 ACC:0.7641 AUROC:0.8431 Precision:0.7383 Recall:0.8182 F1:0.7762 AUPR:0.8241
# Epoch:269 Train_loss:4.0232 ACC:0.7624 AUROC:0.8428 Precision:0.7349 Recall:0.8211 F1:0.7756 AUPR:0.8239
# Epoch:270 Train_loss:4.0569 ACC:0.7611 AUROC:0.8394 Precision:0.7343 Recall:0.8183 F1:0.7740 AUPR:0.8212
# Epoch:270 Val_loss:3.9588 ACC:0.7716 AUROC:0.8492 Precision:0.7502 Recall:0.8141 F1:0.7808 AUPR:0.8266
# ==> Saving model...
# Epoch:271 Train_loss:4.0402 ACC:0.7628 AUROC:0.8413 Precision:0.7363 Recall:0.8189 F1:0.7754 AUPR:0.8218
# Epoch:272 Train_loss:4.0161 ACC:0.7642 AUROC:0.8435 Precision:0.7371 Recall:0.8214 F1:0.7770 AUPR:0.8244
# Epoch:273 Train_loss:4.0415 ACC:0.7628 AUROC:0.8407 Precision:0.7352 Recall:0.8215 F1:0.7759 AUPR:0.8206
# Epoch:274 Train_loss:4.0437 ACC:0.7636 AUROC:0.8403 Precision:0.7354 Recall:0.8235 F1:0.7770 AUPR:0.8191
# Epoch:275 Train_loss:4.0257 ACC:0.7628 AUROC:0.8424 Precision:0.7352 Recall:0.8216 F1:0.7760 AUPR:0.8230
# Epoch:275 Val_loss:3.9422 ACC:0.7734 AUROC:0.8517 Precision:0.7573 Recall:0.8049 F1:0.7804 AUPR:0.8300
# ==> Saving model...
# Epoch:276 Train_loss:4.0154 ACC:0.7656 AUROC:0.8438 Precision:0.7385 Recall:0.8224 F1:0.7782 AUPR:0.8246
# Epoch:277 Train_loss:4.0077 ACC:0.7656 AUROC:0.8442 Precision:0.7387 Recall:0.8220 F1:0.7781 AUPR:0.8263
# Epoch:278 Train_loss:4.0058 ACC:0.7639 AUROC:0.8445 Precision:0.7371 Recall:0.8203 F1:0.7765 AUPR:0.8268
# Epoch:279 Train_loss:4.0185 ACC:0.7637 AUROC:0.8432 Precision:0.7365 Recall:0.8211 F1:0.7765 AUPR:0.8244
# Epoch:280 Train_loss:4.0182 ACC:0.7647 AUROC:0.8434 Precision:0.7385 Recall:0.8196 F1:0.7769 AUPR:0.8248
# Epoch:280 Val_loss:3.9104 ACC:0.7751 AUROC:0.8535 Precision:0.7464 Recall:0.8332 F1:0.7874 AUPR:0.8318
# ==> Saving model...
# ==> Saving model...
# Epoch:281 Train_loss:4.0065 ACC:0.7657 AUROC:0.8444 Precision:0.7385 Recall:0.8227 F1:0.7783 AUPR:0.8253
# Epoch:282 Train_loss:4.0135 ACC:0.7633 AUROC:0.8436 Precision:0.7364 Recall:0.8202 F1:0.7760 AUPR:0.8242
# Epoch:283 Train_loss:4.0125 ACC:0.7652 AUROC:0.8439 Precision:0.7376 Recall:0.8233 F1:0.7781 AUPR:0.8248
# Epoch:284 Train_loss:4.0098 ACC:0.7667 AUROC:0.8441 Precision:0.7393 Recall:0.8239 F1:0.7793 AUPR:0.8249
# Epoch:285 Train_loss:4.0094 ACC:0.7653 AUROC:0.8441 Precision:0.7386 Recall:0.8214 F1:0.7778 AUPR:0.8248
# Epoch:285 Val_loss:3.9340 ACC:0.7772 AUROC:0.8518 Precision:0.7582 Recall:0.8137 F1:0.7850 AUPR:0.8295
# Epoch:286 Train_loss:4.0153 ACC:0.7633 AUROC:0.8435 Precision:0.7363 Recall:0.8205 F1:0.7761 AUPR:0.8244
# Epoch:287 Train_loss:4.0191 ACC:0.7641 AUROC:0.8431 Precision:0.7367 Recall:0.8220 F1:0.7770 AUPR:0.8240
# Epoch:288 Train_loss:4.0127 ACC:0.7652 AUROC:0.8438 Precision:0.7388 Recall:0.8204 F1:0.7775 AUPR:0.8246
# Epoch:289 Train_loss:4.0202 ACC:0.7647 AUROC:0.8430 Precision:0.7367 Recall:0.8239 F1:0.7779 AUPR:0.8231
# Epoch:290 Train_loss:4.0088 ACC:0.7649 AUROC:0.8442 Precision:0.7384 Recall:0.8207 F1:0.7774 AUPR:0.8253
# Epoch:290 Val_loss:3.9140 ACC:0.7766 AUROC:0.8534 Precision:0.7544 Recall:0.8196 F1:0.7857 AUPR:0.8322
# ==> Saving model...
# Epoch:291 Train_loss:4.0105 ACC:0.7649 AUROC:0.8441 Precision:0.7382 Recall:0.8210 F1:0.7774 AUPR:0.8255
# Epoch:292 Train_loss:4.0193 ACC:0.7644 AUROC:0.8434 Precision:0.7372 Recall:0.8217 F1:0.7772 AUPR:0.8251
# Epoch:293 Train_loss:4.0053 ACC:0.7653 AUROC:0.8446 Precision:0.7382 Recall:0.8222 F1:0.7779 AUPR:0.8255
# Epoch:294 Train_loss:4.0097 ACC:0.7656 AUROC:0.8439 Precision:0.7387 Recall:0.8221 F1:0.7782 AUPR:0.8239
# Epoch:295 Train_loss:4.0045 ACC:0.7651 AUROC:0.8446 Precision:0.7386 Recall:0.8209 F1:0.7775 AUPR:0.8261
# Epoch:295 Val_loss:3.9247 ACC:0.7782 AUROC:0.8522 Precision:0.7508 Recall:0.8325 F1:0.7896 AUPR:0.8293
# Epoch:296 Train_loss:4.0105 ACC:0.7645 AUROC:0.8444 Precision:0.7387 Recall:0.8186 F1:0.7766 AUPR:0.8260
# Epoch:297 Train_loss:3.9830 ACC:0.7679 AUROC:0.8469 Precision:0.7416 Recall:0.8222 F1:0.7798 AUPR:0.8282
# Epoch:298 Train_loss:4.0013 ACC:0.7663 AUROC:0.8451 Precision:0.7392 Recall:0.8227 F1:0.7788 AUPR:0.8262
# Epoch:299 Train_loss:4.0125 ACC:0.7635 AUROC:0.8437 Precision:0.7363 Recall:0.8210 F1:0.7763 AUPR:0.8246
# Epoch:300 Train_loss:3.9996 ACC:0.7662 AUROC:0.8451 Precision:0.7389 Recall:0.8234 F1:0.7789 AUPR:0.8256
# Epoch:300 Val_loss:3.9158 ACC:0.7719 AUROC:0.8535 Precision:0.7482 Recall:0.8195 F1:0.7822 AUPR:0.8333
# ==> Saving model...
# Epoch:301 Train_loss:3.9996 ACC:0.7653 AUROC:0.8451 Precision:0.7387 Recall:0.8210 F1:0.7777 AUPR:0.8266
# Epoch:302 Train_loss:4.0175 ACC:0.7639 AUROC:0.8432 Precision:0.7369 Recall:0.8207 F1:0.7766 AUPR:0.8238
# Epoch:303 Train_loss:3.9950 ACC:0.7668 AUROC:0.8455 Precision:0.7396 Recall:0.8235 F1:0.7793 AUPR:0.8255
# Epoch:304 Train_loss:3.9910 ACC:0.7678 AUROC:0.8461 Precision:0.7410 Recall:0.8233 F1:0.7800 AUPR:0.8257
# Epoch:305 Train_loss:3.9873 ACC:0.7677 AUROC:0.8462 Precision:0.7408 Recall:0.8237 F1:0.7800 AUPR:0.8284
# Epoch:305 Val_loss:3.8915 ACC:0.7782 AUROC:0.8555 Precision:0.7564 Recall:0.8208 F1:0.7873 AUPR:0.8354
# ==> Saving model...
# Epoch:306 Train_loss:3.9924 ACC:0.7677 AUROC:0.8457 Precision:0.7411 Recall:0.8230 F1:0.7799 AUPR:0.8269
# Epoch:307 Train_loss:3.9954 ACC:0.7664 AUROC:0.8458 Precision:0.7399 Recall:0.8215 F1:0.7786 AUPR:0.8281
# Epoch:308 Train_loss:3.9787 ACC:0.7682 AUROC:0.8474 Precision:0.7425 Recall:0.8213 F1:0.7799 AUPR:0.8299
# Epoch:309 Train_loss:3.9913 ACC:0.7674 AUROC:0.8463 Precision:0.7410 Recall:0.8223 F1:0.7795 AUPR:0.8279
# Epoch:310 Train_loss:3.9924 ACC:0.7665 AUROC:0.8459 Precision:0.7403 Recall:0.8212 F1:0.7786 AUPR:0.8272
# Epoch:310 Val_loss:3.9290 ACC:0.7772 AUROC:0.8516 Precision:0.7524 Recall:0.8265 F1:0.7877 AUPR:0.8284
# ==> Saving model...
# Epoch:311 Train_loss:4.0019 ACC:0.7672 AUROC:0.8451 Precision:0.7401 Recall:0.8235 F1:0.7796 AUPR:0.8268
# Epoch:312 Train_loss:3.9926 ACC:0.7667 AUROC:0.8462 Precision:0.7404 Recall:0.8214 F1:0.7788 AUPR:0.8285
# Epoch:313 Train_loss:3.9915 ACC:0.7673 AUROC:0.8461 Precision:0.7408 Recall:0.8223 F1:0.7794 AUPR:0.8262
# Epoch:314 Train_loss:3.9849 ACC:0.7680 AUROC:0.8468 Precision:0.7413 Recall:0.8233 F1:0.7802 AUPR:0.8282
# Epoch:315 Train_loss:3.9856 ACC:0.7671 AUROC:0.8466 Precision:0.7406 Recall:0.8223 F1:0.7793 AUPR:0.8276
# Epoch:315 Val_loss:3.9367 ACC:0.7717 AUROC:0.8521 Precision:0.7383 Recall:0.8420 F1:0.7868 AUPR:0.8326
# Epoch:316 Train_loss:3.9683 ACC:0.7697 AUROC:0.8483 Precision:0.7440 Recall:0.8224 F1:0.7812 AUPR:0.8296
# Epoch:317 Train_loss:3.9803 ACC:0.7691 AUROC:0.8471 Precision:0.7419 Recall:0.8252 F1:0.7813 AUPR:0.8276
# Epoch:318 Train_loss:3.9739 ACC:0.7701 AUROC:0.8477 Precision:0.7440 Recall:0.8235 F1:0.7817 AUPR:0.8292
# Epoch:319 Train_loss:3.9749 ACC:0.7697 AUROC:0.8478 Precision:0.7428 Recall:0.8251 F1:0.7818 AUPR:0.8284
# Epoch:320 Train_loss:3.9829 ACC:0.7671 AUROC:0.8468 Precision:0.7405 Recall:0.8223 F1:0.7793 AUPR:0.8291
# Epoch:320 Val_loss:3.8962 ACC:0.7802 AUROC:0.8552 Precision:0.7574 Recall:0.8246 F1:0.7895 AUPR:0.8354
# ==> Saving model...
# Epoch:321 Train_loss:3.9710 ACC:0.7683 AUROC:0.8477 Precision:0.7411 Recall:0.8249 F1:0.7807 AUPR:0.8301
# Epoch:322 Train_loss:3.9805 ACC:0.7669 AUROC:0.8469 Precision:0.7400 Recall:0.8230 F1:0.7793 AUPR:0.8287
# Epoch:323 Train_loss:3.9688 ACC:0.7700 AUROC:0.8483 Precision:0.7437 Recall:0.8238 F1:0.7817 AUPR:0.8307
# Epoch:324 Train_loss:3.9633 ACC:0.7700 AUROC:0.8487 Precision:0.7428 Recall:0.8260 F1:0.7822 AUPR:0.8300
# Epoch:325 Train_loss:3.9702 ACC:0.7689 AUROC:0.8483 Precision:0.7430 Recall:0.8221 F1:0.7806 AUPR:0.8315
# Epoch:325 Val_loss:3.9073 ACC:0.7783 AUROC:0.8546 Precision:0.7496 Recall:0.8362 F1:0.7905 AUPR:0.8353
# Epoch:326 Train_loss:3.9561 ACC:0.7706 AUROC:0.8496 Precision:0.7446 Recall:0.8237 F1:0.7821 AUPR:0.8321
# Epoch:327 Train_loss:3.9631 ACC:0.7701 AUROC:0.8487 Precision:0.7430 Recall:0.8260 F1:0.7823 AUPR:0.8303
# Epoch:328 Train_loss:3.9598 ACC:0.7690 AUROC:0.8488 Precision:0.7420 Recall:0.8249 F1:0.7812 AUPR:0.8306
# Epoch:329 Train_loss:3.9858 ACC:0.7681 AUROC:0.8467 Precision:0.7420 Recall:0.8220 F1:0.7800 AUPR:0.8279
# Epoch:330 Train_loss:3.9811 ACC:0.7684 AUROC:0.8475 Precision:0.7426 Recall:0.8216 F1:0.7801 AUPR:0.8300
# Epoch:330 Val_loss:3.8720 ACC:0.7782 AUROC:0.8579 Precision:0.7448 Recall:0.8466 F1:0.7924 AUPR:0.8398
# ==> Saving model...
# ==> Saving model...
# Epoch:331 Train_loss:3.9690 ACC:0.7683 AUROC:0.8481 Precision:0.7418 Recall:0.8229 F1:0.7803 AUPR:0.8293
# Epoch:332 Train_loss:3.9729 ACC:0.7687 AUROC:0.8476 Precision:0.7419 Recall:0.8240 F1:0.7808 AUPR:0.8296
# Epoch:333 Train_loss:3.9648 ACC:0.7699 AUROC:0.8483 Precision:0.7434 Recall:0.8243 F1:0.7818 AUPR:0.8292
# Epoch:334 Train_loss:3.9722 ACC:0.7680 AUROC:0.8479 Precision:0.7416 Recall:0.8227 F1:0.7801 AUPR:0.8296
# Epoch:335 Train_loss:3.9762 ACC:0.7682 AUROC:0.8472 Precision:0.7417 Recall:0.8230 F1:0.7802 AUPR:0.8275
# Epoch:335 Val_loss:3.8913 ACC:0.7774 AUROC:0.8552 Precision:0.7459 Recall:0.8416 F1:0.7908 AUPR:0.8340
# Epoch:336 Train_loss:3.9676 ACC:0.7696 AUROC:0.8484 Precision:0.7432 Recall:0.8241 F1:0.7815 AUPR:0.8300
# Epoch:337 Train_loss:3.9605 ACC:0.7679 AUROC:0.8488 Precision:0.7414 Recall:0.8228 F1:0.7800 AUPR:0.8301
# Epoch:338 Train_loss:3.9639 ACC:0.7699 AUROC:0.8488 Precision:0.7434 Recall:0.8243 F1:0.7818 AUPR:0.8302
# Epoch:339 Train_loss:3.9578 ACC:0.7705 AUROC:0.8494 Precision:0.7438 Recall:0.8253 F1:0.7824 AUPR:0.8322
# Epoch:340 Train_loss:3.9762 ACC:0.7681 AUROC:0.8476 Precision:0.7410 Recall:0.8242 F1:0.7804 AUPR:0.8291
# Epoch:340 Val_loss:3.9066 ACC:0.7757 AUROC:0.8540 Precision:0.7584 Recall:0.8089 F1:0.7828 AUPR:0.8303
# ==> Saving model...
# Epoch:341 Train_loss:3.9626 ACC:0.7694 AUROC:0.8488 Precision:0.7428 Recall:0.8243 F1:0.7814 AUPR:0.8301
# Epoch:342 Train_loss:3.9706 ACC:0.7694 AUROC:0.8477 Precision:0.7431 Recall:0.8234 F1:0.7812 AUPR:0.8289
# Epoch:343 Train_loss:3.9598 ACC:0.7702 AUROC:0.8491 Precision:0.7434 Recall:0.8251 F1:0.7821 AUPR:0.8311
# Epoch:344 Train_loss:3.9640 ACC:0.7708 AUROC:0.8490 Precision:0.7447 Recall:0.8241 F1:0.7824 AUPR:0.8309
# Epoch:345 Train_loss:3.9683 ACC:0.7690 AUROC:0.8481 Precision:0.7422 Recall:0.8244 F1:0.7811 AUPR:0.8281
# Epoch:345 Val_loss:3.8906 ACC:0.7793 AUROC:0.8560 Precision:0.7593 Recall:0.8177 F1:0.7875 AUPR:0.8333
# Epoch:346 Train_loss:3.9557 ACC:0.7701 AUROC:0.8498 Precision:0.7436 Recall:0.8244 F1:0.7819 AUPR:0.8306
# Epoch:347 Train_loss:3.9574 ACC:0.7696 AUROC:0.8493 Precision:0.7430 Recall:0.8245 F1:0.7816 AUPR:0.8307
# Epoch:348 Train_loss:3.9377 ACC:0.7714 AUROC:0.8511 Precision:0.7442 Recall:0.8270 F1:0.7834 AUPR:0.8335
# Epoch:349 Train_loss:3.9477 ACC:0.7721 AUROC:0.8503 Precision:0.7459 Recall:0.8256 F1:0.7837 AUPR:0.8322
# Epoch:350 Train_loss:3.9687 ACC:0.7680 AUROC:0.8482 Precision:0.7409 Recall:0.8242 F1:0.7803 AUPR:0.8309
# Epoch:350 Val_loss:3.8785 ACC:0.7781 AUROC:0.8569 Precision:0.7514 Recall:0.8308 F1:0.7891 AUPR:0.8347
# ==> Saving model...
# Epoch:351 Train_loss:3.9616 ACC:0.7694 AUROC:0.8491 Precision:0.7430 Recall:0.8238 F1:0.7813 AUPR:0.8317
# Epoch:352 Train_loss:3.9589 ACC:0.7710 AUROC:0.8489 Precision:0.7443 Recall:0.8258 F1:0.7829 AUPR:0.8303
# Epoch:353 Train_loss:3.9458 ACC:0.7717 AUROC:0.8505 Precision:0.7448 Recall:0.8268 F1:0.7837 AUPR:0.8322
# Epoch:354 Train_loss:3.9520 ACC:0.7709 AUROC:0.8497 Precision:0.7446 Recall:0.8246 F1:0.7826 AUPR:0.8320
# Epoch:355 Train_loss:3.9469 ACC:0.7708 AUROC:0.8505 Precision:0.7445 Recall:0.8244 F1:0.7824 AUPR:0.8319
# Epoch:355 Val_loss:3.8668 ACC:0.7778 AUROC:0.8583 Precision:0.7455 Recall:0.8433 F1:0.7914 AUPR:0.8374
# ==> Saving model...
# Epoch:356 Train_loss:3.9588 ACC:0.7703 AUROC:0.8491 Precision:0.7432 Recall:0.8259 F1:0.7824 AUPR:0.8305
# Epoch:357 Train_loss:3.9518 ACC:0.7729 AUROC:0.8499 Precision:0.7465 Recall:0.8264 F1:0.7845 AUPR:0.8313
# Epoch:358 Train_loss:3.9532 ACC:0.7698 AUROC:0.8495 Precision:0.7435 Recall:0.8238 F1:0.7816 AUPR:0.8311
# Epoch:359 Train_loss:3.9520 ACC:0.7707 AUROC:0.8499 Precision:0.7443 Recall:0.8246 F1:0.7824 AUPR:0.8318
# Epoch:360 Train_loss:3.9528 ACC:0.7722 AUROC:0.8500 Precision:0.7455 Recall:0.8267 F1:0.7840 AUPR:0.8333
# Epoch:360 Val_loss:3.8798 ACC:0.7802 AUROC:0.8579 Precision:0.7655 Recall:0.8080 F1:0.7861 AUPR:0.8379
# ==> Saving model...
# Epoch:361 Train_loss:3.9523 ACC:0.7705 AUROC:0.8498 Precision:0.7446 Recall:0.8234 F1:0.7820 AUPR:0.8326
# Epoch:362 Train_loss:3.9539 ACC:0.7707 AUROC:0.8492 Precision:0.7438 Recall:0.8257 F1:0.7826 AUPR:0.8310
# Epoch:363 Train_loss:3.9651 ACC:0.7689 AUROC:0.8482 Precision:0.7410 Recall:0.8269 F1:0.7816 AUPR:0.8302
# Epoch:364 Train_loss:3.9410 ACC:0.7722 AUROC:0.8509 Precision:0.7462 Recall:0.8251 F1:0.7837 AUPR:0.8324
# Epoch:365 Train_loss:3.9430 ACC:0.7717 AUROC:0.8506 Precision:0.7448 Recall:0.8265 F1:0.7835 AUPR:0.8327
# Epoch:365 Val_loss:3.8662 ACC:0.7815 AUROC:0.8586 Precision:0.7611 Recall:0.8209 F1:0.7899 AUPR:0.8382
# ==> Saving model...
# Epoch:366 Train_loss:3.9374 ACC:0.7718 AUROC:0.8509 Precision:0.7457 Recall:0.8250 F1:0.7833 AUPR:0.8332
# Epoch:367 Train_loss:3.9517 ACC:0.7711 AUROC:0.8496 Precision:0.7448 Recall:0.8249 F1:0.7828 AUPR:0.8305
# Epoch:368 Train_loss:3.9464 ACC:0.7696 AUROC:0.8506 Precision:0.7433 Recall:0.8238 F1:0.7815 AUPR:0.8334
# Epoch:369 Train_loss:3.9519 ACC:0.7698 AUROC:0.8499 Precision:0.7440 Recall:0.8227 F1:0.7814 AUPR:0.8331
# Epoch:370 Train_loss:3.9384 ACC:0.7717 AUROC:0.8512 Precision:0.7447 Recall:0.8268 F1:0.7836 AUPR:0.8326
# Epoch:370 Val_loss:3.8799 ACC:0.7818 AUROC:0.8568 Precision:0.7590 Recall:0.8256 F1:0.7909 AUPR:0.8370
# ==> Saving model...
# Epoch:371 Train_loss:3.9439 ACC:0.7712 AUROC:0.8503 Precision:0.7441 Recall:0.8267 F1:0.7832 AUPR:0.8322
# Epoch:372 Train_loss:3.9600 ACC:0.7696 AUROC:0.8488 Precision:0.7429 Recall:0.8246 F1:0.7816 AUPR:0.8302
# Epoch:373 Train_loss:3.9437 ACC:0.7719 AUROC:0.8506 Precision:0.7455 Recall:0.8254 F1:0.7835 AUPR:0.8320
# Epoch:374 Train_loss:3.9426 ACC:0.7714 AUROC:0.8508 Precision:0.7455 Recall:0.8240 F1:0.7828 AUPR:0.8329
# ...
# Epoch:587 Train_loss:3.7573 ACC:0.7866 AUROC:0.8680 Precision:0.7621 Recall:0.8332 F1:0.7961 AUPR:0.8546
# Epoch:588 Train_loss:3.7357 ACC:0.7886 AUROC:0.8701 Precision:0.7649 Recall:0.8336 F1:0.7977 AUPR:0.8568
# Epoch:589 Train_loss:3.7675 ACC:0.7870 AUROC:0.8675 Precision:0.7626 Recall:0.8335 F1:0.7965 AUPR:0.8539
# Epoch:590 Train_loss:3.7495 ACC:0.7884 AUROC:0.8687 Precision:0.7636 Recall:0.8354 F1:0.7979 AUPR:0.8542
# Epoch:590 Val_loss:3.7571 ACC:0.7887 AUROC:0.8686 Precision:0.7699 Recall:0.8237 F1:0.7959 AUPR:0.8534
# ==> Saving model...
# Epoch:591 Train_loss:3.7452 ACC:0.7877 AUROC:0.8691 Precision:0.7634 Recall:0.8339 F1:0.7971 AUPR:0.8560
# Epoch:592 Train_loss:3.7542 ACC:0.7870 AUROC:0.8684 Precision:0.7630 Recall:0.8327 F1:0.7963 AUPR:0.8552
# Epoch:593 Train_loss:3.7542 ACC:0.7867 AUROC:0.8688 Precision:0.7632 Recall:0.8313 F1:0.7958 AUPR:0.8561
# Epoch:594 Train_loss:3.7637 ACC:0.7863 AUROC:0.8677 Precision:0.7618 Recall:0.8331 F1:0.7958 AUPR:0.8545
# Epoch:595 Train_loss:3.7343 ACC:0.7894 AUROC:0.8706 Precision:0.7657 Recall:0.8340 F1:0.7984 AUPR:0.8595
# Epoch:595 Val_loss:3.7500 ACC:0.7925 AUROC:0.8697 Precision:0.7719 Recall:0.8307 F1:0.8002 AUPR:0.8550
# Epoch:596 Train_loss:3.7589 ACC:0.7873 AUROC:0.8683 Precision:0.7637 Recall:0.8321 F1:0.7964 AUPR:0.8547
# Epoch:597 Train_loss:3.7483 ACC:0.7887 AUROC:0.8695 Precision:0.7654 Recall:0.8327 F1:0.7976 AUPR:0.8561
# Epoch:598 Train_loss:3.7321 ACC:0.7897 AUROC:0.8703 Precision:0.7654 Recall:0.8353 F1:0.7989 AUPR:0.8568
# Epoch:599 Train_loss:3.7345 ACC:0.7906 AUROC:0.8704 Precision:0.7669 Recall:0.8350 F1:0.7995 AUPR:0.8570
# Epoch:600 Train_loss:3.7433 ACC:0.7882 AUROC:0.8696 Precision:0.7648 Recall:0.8322 F1:0.7971 AUPR:0.8573
# Epoch:600 Val_loss:3.7600 ACC:0.7911 AUROC:0.8687 Precision:0.7777 Recall:0.8151 F1:0.7960 AUPR:0.8537
# ==> Saving model...
# Epoch:601 Train_loss:3.7498 ACC:0.7868 AUROC:0.8687 Precision:0.7621 Recall:0.8339 F1:0.7964 AUPR:0.8556
# Epoch:602 Train_loss:3.7656 ACC:0.7858 AUROC:0.8677 Precision:0.7614 Recall:0.8325 F1:0.7953 AUPR:0.8543
# Epoch:603 Train_loss:3.7342 ACC:0.7897 AUROC:0.8703 Precision:0.7664 Recall:0.8335 F1:0.7986 AUPR:0.8572
# Epoch:604 Train_loss:3.7413 ACC:0.7897 AUROC:0.8694 Precision:0.7660 Recall:0.8343 F1:0.7987 AUPR:0.8556
# Epoch:605 Train_loss:3.7353 ACC:0.7902 AUROC:0.8701 Precision:0.7651 Recall:0.8377 F1:0.7997 AUPR:0.8564
# Epoch:605 Val_loss:3.7378 ACC:0.7915 AUROC:0.8701 Precision:0.7674 Recall:0.8365 F1:0.8005 AUPR:0.8554
# Epoch:606 Train_loss:3.7240 ACC:0.7911 AUROC:0.8714 Precision:0.7674 Recall:0.8354 F1:0.8000 AUPR:0.8590
# Epoch:607 Train_loss:3.7374 ACC:0.7874 AUROC:0.8701 Precision:0.7632 Recall:0.8334 F1:0.7968 AUPR:0.8577
# Epoch:608 Train_loss:3.7399 ACC:0.7892 AUROC:0.8702 Precision:0.7653 Recall:0.8344 F1:0.7983 AUPR:0.8586
# Epoch:609 Train_loss:3.7657 ACC:0.7875 AUROC:0.8677 Precision:0.7635 Recall:0.8330 F1:0.7967 AUPR:0.8540
# Epoch:610 Train_loss:3.7498 ACC:0.7865 AUROC:0.8692 Precision:0.7635 Recall:0.8302 F1:0.7954 AUPR:0.8570
# Epoch:610 Val_loss:3.7658 ACC:0.7906 AUROC:0.8680 Precision:0.7692 Recall:0.8304 F1:0.7986 AUPR:0.8519
# ==> Saving model...
# Epoch:611 Train_loss:3.7706 ACC:0.7851 AUROC:0.8672 Precision:0.7612 Recall:0.8308 F1:0.7945 AUPR:0.8544
# Epoch:612 Train_loss:3.7811 ACC:0.7846 AUROC:0.8662 Precision:0.7613 Recall:0.8290 F1:0.7937 AUPR:0.8527
# Epoch:613 Train_loss:3.7816 ACC:0.7847 AUROC:0.8665 Precision:0.7618 Recall:0.8284 F1:0.7937 AUPR:0.8537
# Epoch:614 Train_loss:3.7744 ACC:0.7859 AUROC:0.8668 Precision:0.7625 Recall:0.8307 F1:0.7951 AUPR:0.8539
# Epoch:615 Train_loss:3.7770 ACC:0.7854 AUROC:0.8667 Precision:0.7624 Recall:0.8291 F1:0.7944 AUPR:0.8533
# Epoch:615 Val_loss:3.7830 ACC:0.7869 AUROC:0.8660 Precision:0.7689 Recall:0.8209 F1:0.7940 AUPR:0.8506
# Epoch:616 Train_loss:3.7526 ACC:0.7869 AUROC:0.8688 Precision:0.7633 Recall:0.8316 F1:0.7960 AUPR:0.8564
# Epoch:617 Train_loss:3.7504 ACC:0.7889 AUROC:0.8691 Precision:0.7651 Recall:0.8339 F1:0.7980 AUPR:0.8555
# Epoch:618 Train_loss:3.7525 ACC:0.7872 AUROC:0.8687 Precision:0.7635 Recall:0.8322 F1:0.7964 AUPR:0.8556
# Epoch:619 Train_loss:3.7521 ACC:0.7880 AUROC:0.8688 Precision:0.7641 Recall:0.8333 F1:0.7972 AUPR:0.8552
# Epoch:620 Train_loss:3.7628 ACC:0.7860 AUROC:0.8677 Precision:0.7622 Recall:0.8313 F1:0.7953 AUPR:0.8543
# Epoch:620 Val_loss:3.7602 ACC:0.7903 AUROC:0.8674 Precision:0.7674 Recall:0.8330 F1:0.7988 AUPR:0.8489
# ==> Saving model...
# Epoch:621 Train_loss:3.7733 ACC:0.7858 AUROC:0.8668 Precision:0.7624 Recall:0.8304 F1:0.7949 AUPR:0.8538
# Epoch:622 Train_loss:3.7447 ACC:0.7883 AUROC:0.8694 Precision:0.7644 Recall:0.8336 F1:0.7975 AUPR:0.8570
# Epoch:623 Train_loss:3.7571 ACC:0.7886 AUROC:0.8684 Precision:0.7651 Recall:0.8330 F1:0.7976 AUPR:0.8544
# Epoch:624 Train_loss:3.7372 ACC:0.7889 AUROC:0.8702 Precision:0.7643 Recall:0.8354 F1:0.7983 AUPR:0.8573
# Epoch:625 Train_loss:3.7623 ACC:0.7878 AUROC:0.8680 Precision:0.7644 Recall:0.8321 F1:0.7968 AUPR:0.8549
# Epoch:625 Val_loss:3.7534 ACC:0.7876 AUROC:0.8689 Precision:0.7669 Recall:0.8259 F1:0.7953 AUPR:0.8537
# Epoch:626 Train_loss:3.7366 ACC:0.7887 AUROC:0.8704 Precision:0.7659 Recall:0.8316 F1:0.7974 AUPR:0.8582
# Epoch:627 Train_loss:3.7406 ACC:0.7898 AUROC:0.8698 Precision:0.7663 Recall:0.8340 F1:0.7987 AUPR:0.8563
# Epoch:628 Train_loss:3.7418 ACC:0.7878 AUROC:0.8694 Precision:0.7647 Recall:0.8315 F1:0.7967 AUPR:0.8563
# Epoch:629 Train_loss:3.7562 ACC:0.7881 AUROC:0.8686 Precision:0.7651 Recall:0.8314 F1:0.7969 AUPR:0.8558
# Epoch:630 Train_loss:3.7606 ACC:0.7868 AUROC:0.8680 Precision:0.7626 Recall:0.8329 F1:0.7962 AUPR:0.8562
# Epoch:630 Val_loss:3.7486 ACC:0.7899 AUROC:0.8700 Precision:0.7780 Recall:0.8111 F1:0.7942 AUPR:0.8564
# ==> Saving model...
# Epoch:631 Train_loss:3.7461 ACC:0.7878 AUROC:0.8693 Precision:0.7641 Recall:0.8328 F1:0.7970 AUPR:0.8565
# Epoch:632 Train_loss:3.7521 ACC:0.7880 AUROC:0.8686 Precision:0.7645 Recall:0.8324 F1:0.7970 AUPR:0.8550
# Epoch:633 Train_loss:3.7473 ACC:0.7878 AUROC:0.8692 Precision:0.7639 Recall:0.8331 F1:0.7970 AUPR:0.8558
# Epoch:634 Train_loss:3.7348 ACC:0.7892 AUROC:0.8703 Precision:0.7658 Recall:0.8332 F1:0.7981 AUPR:0.8577
# Epoch:635 Train_loss:3.7366 ACC:0.7897 AUROC:0.8704 Precision:0.7662 Recall:0.8337 F1:0.7986 AUPR:0.8576
# Epoch:635 Val_loss:3.7411 ACC:0.7923 AUROC:0.8704 Precision:0.7745 Recall:0.8245 F1:0.7987 AUPR:0.8554
# ==> Saving model...
# Epoch:636 Train_loss:3.7323 ACC:0.7896 AUROC:0.8706 Precision:0.7666 Recall:0.8326 F1:0.7983 AUPR:0.8585
# Epoch:637 Train_loss:3.7481 ACC:0.7873 AUROC:0.8691 Precision:0.7640 Recall:0.8315 F1:0.7963 AUPR:0.8571
# Epoch:638 Train_loss:3.7324 ACC:0.7888 AUROC:0.8703 Precision:0.7650 Recall:0.8337 F1:0.7979 AUPR:0.8578
# Epoch:639 Train_loss:3.7532 ACC:0.7879 AUROC:0.8686 Precision:0.7640 Recall:0.8333 F1:0.7971 AUPR:0.8554
# Epoch:640 Train_loss:3.7340 ACC:0.7887 AUROC:0.8704 Precision:0.7651 Recall:0.8334 F1:0.7978 AUPR:0.8577
# Epoch:640 Val_loss:3.7623 ACC:0.7908 AUROC:0.8684 Precision:0.7704 Recall:0.8282 F1:0.7982 AUPR:0.8528
# ==> Saving model...
# Epoch:641 Train_loss:3.7348 ACC:0.7883 AUROC:0.8702 Precision:0.7650 Recall:0.8320 F1:0.7971 AUPR:0.8579
# Epoch:642 Train_loss:3.7379 ACC:0.7890 AUROC:0.8700 Precision:0.7651 Recall:0.8340 F1:0.7981 AUPR:0.8576
# Epoch:643 Train_loss:3.7263 ACC:0.7902 AUROC:0.8710 Precision:0.7668 Recall:0.8340 F1:0.7990 AUPR:0.8588
# Epoch:644 Train_loss:3.7230 ACC:0.7900 AUROC:0.8713 Precision:0.7665 Recall:0.8343 F1:0.7989 AUPR:0.8588
# Epoch:645 Train_loss:3.7142 ACC:0.7901 AUROC:0.8722 Precision:0.7668 Recall:0.8337 F1:0.7989 AUPR:0.8609
# Epoch:645 Val_loss:3.7294 ACC:0.7932 AUROC:0.8711 Precision:0.7728 Recall:0.8307 F1:0.8007 AUPR:0.8564
# ==> Saving model...
# Epoch:646 Train_loss:3.7289 ACC:0.7886 AUROC:0.8708 Precision:0.7655 Recall:0.8320 F1:0.7974 AUPR:0.8584
# Epoch:647 Train_loss:3.7321 ACC:0.7886 AUROC:0.8704 Precision:0.7646 Recall:0.8340 F1:0.7978 AUPR:0.8582
# Epoch:648 Train_loss:3.7342 ACC:0.7895 AUROC:0.8704 Precision:0.7651 Recall:0.8355 F1:0.7988 AUPR:0.8575
# Epoch:649 Train_loss:3.7403 ACC:0.7897 AUROC:0.8698 Precision:0.7661 Recall:0.8341 F1:0.7987 AUPR:0.8572
# Epoch:650 Train_loss:3.7334 ACC:0.7890 AUROC:0.8703 Precision:0.7656 Recall:0.8330 F1:0.7979 AUPR:0.8578
# Epoch:650 Val_loss:3.7424 ACC:0.7899 AUROC:0.8695 Precision:0.7628 Recall:0.8410 F1:0.8000 AUPR:0.8529
# ==> Saving model...
# Epoch:651 Train_loss:3.7279 ACC:0.7892 AUROC:0.8710 Precision:0.7652 Recall:0.8344 F1:0.7983 AUPR:0.8591
# Epoch:652 Train_loss:3.7296 ACC:0.7892 AUROC:0.8706 Precision:0.7654 Recall:0.8340 F1:0.7982 AUPR:0.8578
# Epoch:653 Train_loss:3.7314 ACC:0.7891 AUROC:0.8703 Precision:0.7654 Recall:0.8337 F1:0.7981 AUPR:0.8581
# Epoch:654 Train_loss:3.7243 ACC:0.7900 AUROC:0.8715 Precision:0.7667 Recall:0.8336 F1:0.7988 AUPR:0.8600
# Epoch:655 Train_loss:3.7375 ACC:0.7879 AUROC:0.8702 Precision:0.7648 Recall:0.8315 F1:0.7968 AUPR:0.8587
# Epoch:655 Val_loss:3.7280 ACC:0.7914 AUROC:0.8713 Precision:0.7660 Recall:0.8392 F1:0.8009 AUPR:0.8571
# ==> Saving model...
# Epoch:656 Train_loss:3.7311 ACC:0.7893 AUROC:0.8710 Precision:0.7667 Recall:0.8318 F1:0.7979 AUPR:0.8595
# Epoch:657 Train_loss:3.7290 ACC:0.7878 AUROC:0.8709 Precision:0.7646 Recall:0.8317 F1:0.7968 AUPR:0.8602
# Epoch:658 Train_loss:3.7527 ACC:0.7872 AUROC:0.8692 Precision:0.7642 Recall:0.8307 F1:0.7960 AUPR:0.8575
# Epoch:659 Train_loss:3.7161 ACC:0.7915 AUROC:0.8718 Precision:0.7686 Recall:0.8341 F1:0.8000 AUPR:0.8593
# Epoch:660 Train_loss:3.7180 ACC:0.7919 AUROC:0.8720 Precision:0.7691 Recall:0.8342 F1:0.8004 AUPR:0.8604
# Epoch:660 Val_loss:3.7338 ACC:0.7920 AUROC:0.8710 Precision:0.7794 Recall:0.8142 F1:0.7964 AUPR:0.8553
# ==> Saving model...
# Epoch:661 Train_loss:3.7290 ACC:0.7892 AUROC:0.8709 Precision:0.7665 Recall:0.8317 F1:0.7978 AUPR:0.8587
# Epoch:662 Train_loss:3.7133 ACC:0.7900 AUROC:0.8721 Precision:0.7665 Recall:0.8340 F1:0.7989 AUPR:0.8599
# Epoch:663 Train_loss:3.7183 ACC:0.7912 AUROC:0.8717 Precision:0.7678 Recall:0.8349 F1:0.7999 AUPR:0.8590
# Epoch:664 Train_loss:3.7071 ACC:0.7920 AUROC:0.8727 Precision:0.7683 Recall:0.8362 F1:0.8008 AUPR:0.8598
# Epoch:665 Train_loss:3.7385 ACC:0.7890 AUROC:0.8701 Precision:0.7655 Recall:0.8332 F1:0.7979 AUPR:0.8577
# Epoch:665 Val_loss:3.7145 ACC:0.7913 AUROC:0.8723 Precision:0.7741 Recall:0.8225 F1:0.7975 AUPR:0.8563
# ==> Saving model...
# Epoch:666 Train_loss:3.7367 ACC:0.7896 AUROC:0.8703 Precision:0.7668 Recall:0.8324 F1:0.7983 AUPR:0.8577
# Epoch:667 Train_loss:3.7195 ACC:0.7904 AUROC:0.8719 Precision:0.7676 Recall:0.8332 F1:0.7990 AUPR:0.8599
# Epoch:668 Train_loss:3.7281 ACC:0.7893 AUROC:0.8709 Precision:0.7658 Recall:0.8336 F1:0.7982 AUPR:0.8589
# Epoch:669 Train_loss:3.7221 ACC:0.7893 AUROC:0.8713 Precision:0.7665 Recall:0.8322 F1:0.7980 AUPR:0.8592
# Epoch:670 Train_loss:3.6956 ACC:0.7928 AUROC:0.8737 Precision:0.7698 Recall:0.8354 F1:0.8013 AUPR:0.8622
# Epoch:670 Val_loss:3.6988 ACC:0.7915 AUROC:0.8736 Precision:0.7666 Recall:0.8386 F1:0.8010 AUPR:0.8601
# ==> Saving model...
# ==> Saving model...
# Epoch:671 Train_loss:3.7159 ACC:0.7903 AUROC:0.8720 Precision:0.7663 Recall:0.8354 F1:0.7993 AUPR:0.8605
# Epoch:672 Train_loss:3.7038 ACC:0.7918 AUROC:0.8730 Precision:0.7686 Recall:0.8350 F1:0.8004 AUPR:0.8605
# Epoch:673 Train_loss:3.7037 ACC:0.7916 AUROC:0.8732 Precision:0.7688 Recall:0.8341 F1:0.8001 AUPR:0.8618
# Epoch:674 Train_loss:3.7192 ACC:0.7889 AUROC:0.8715 Precision:0.7662 Recall:0.8316 F1:0.7975 AUPR:0.8598
# Epoch:675 Train_loss:3.7133 ACC:0.7903 AUROC:0.8723 Precision:0.7674 Recall:0.8331 F1:0.7989 AUPR:0.8606
# Epoch:675 Val_loss:3.7231 ACC:0.7913 AUROC:0.8721 Precision:0.7667 Recall:0.8374 F1:0.8005 AUPR:0.8583
# Epoch:676 Train_loss:3.7065 ACC:0.7914 AUROC:0.8728 Precision:0.7684 Recall:0.8342 F1:0.7999 AUPR:0.8607
# Epoch:677 Train_loss:3.7066 ACC:0.7922 AUROC:0.8728 Precision:0.7692 Recall:0.8349 F1:0.8007 AUPR:0.8598
# Epoch:678 Train_loss:3.7053 ACC:0.7919 AUROC:0.8731 Precision:0.7694 Recall:0.8337 F1:0.8003 AUPR:0.8617
# Epoch:679 Train_loss:3.7029 ACC:0.7923 AUROC:0.8732 Precision:0.7701 Recall:0.8333 F1:0.8004 AUPR:0.8611
# Epoch:680 Train_loss:3.7033 ACC:0.7916 AUROC:0.8730 Precision:0.7690 Recall:0.8337 F1:0.8001 AUPR:0.8613
# Epoch:680 Val_loss:3.7255 ACC:0.7931 AUROC:0.8716 Precision:0.7698 Recall:0.8364 F1:0.8017 AUPR:0.8566
# ==> Saving model...
# Epoch:681 Train_loss:3.7050 ACC:0.7905 AUROC:0.8730 Precision:0.7675 Recall:0.8335 F1:0.7992 AUPR:0.8607
# Epoch:682 Train_loss:3.7067 ACC:0.7914 AUROC:0.8727 Precision:0.7680 Recall:0.8350 F1:0.8001 AUPR:0.8600
# Epoch:683 Train_loss:3.6996 ACC:0.7923 AUROC:0.8736 Precision:0.7689 Recall:0.8358 F1:0.8010 AUPR:0.8618
# Epoch:684 Train_loss:3.7037 ACC:0.7920 AUROC:0.8732 Precision:0.7695 Recall:0.8338 F1:0.8004 AUPR:0.8614
# Epoch:685 Train_loss:3.6812 ACC:0.7943 AUROC:0.8749 Precision:0.7716 Recall:0.8362 F1:0.8026 AUPR:0.8628
# Epoch:685 Val_loss:3.6991 ACC:0.7941 AUROC:0.8738 Precision:0.7761 Recall:0.8270 F1:0.8007 AUPR:0.8587
# ==> Saving model...
# Epoch:686 Train_loss:3.7051 ACC:0.7923 AUROC:0.8728 Precision:0.7693 Recall:0.8349 F1:0.8008 AUPR:0.8615
# Epoch:687 Train_loss:3.6937 ACC:0.7914 AUROC:0.8740 Precision:0.7694 Recall:0.8323 F1:0.7996 AUPR:0.8628
# Epoch:688 Train_loss:3.6820 ACC:0.7949 AUROC:0.8752 Precision:0.7728 Recall:0.8355 F1:0.8029 AUPR:0.8638
# Epoch:689 Train_loss:3.6844 ACC:0.7933 AUROC:0.8747 Precision:0.7714 Recall:0.8336 F1:0.8013 AUPR:0.8633
# Epoch:690 Train_loss:3.7050 ACC:0.7918 AUROC:0.8729 Precision:0.7695 Recall:0.8332 F1:0.8001 AUPR:0.8612
# Epoch:690 Val_loss:3.7148 ACC:0.7933 AUROC:0.8731 Precision:0.7637 Recall:0.8495 F1:0.8043 AUPR:0.8591
# ==> Saving model...
# Epoch:691 Train_loss:3.6902 ACC:0.7927 AUROC:0.8742 Precision:0.7694 Recall:0.8359 F1:0.8013 AUPR:0.8631
# Epoch:692 Train_loss:3.7046 ACC:0.7927 AUROC:0.8731 Precision:0.7691 Recall:0.8365 F1:0.8014 AUPR:0.8609
# Epoch:693 Train_loss:3.6863 ACC:0.7935 AUROC:0.8744 Precision:0.7701 Recall:0.8367 F1:0.8020 AUPR:0.8619
# Epoch:694 Train_loss:3.6992 ACC:0.7922 AUROC:0.8732 Precision:0.7685 Recall:0.8362 F1:0.8009 AUPR:0.8608
# Epoch:695 Train_loss:3.6620 ACC:0.7959 AUROC:0.8766 Precision:0.7733 Recall:0.8374 F1:0.8040 AUPR:0.8649
# Epoch:695 Val_loss:3.7295 ACC:0.7918 AUROC:0.8709 Precision:0.7691 Recall:0.8338 F1:0.8002 AUPR:0.8548
# Epoch:696 Train_loss:3.6960 ACC:0.7930 AUROC:0.8737 Precision:0.7700 Recall:0.8356 F1:0.8015 AUPR:0.8621
# Epoch:697 Train_loss:3.6914 ACC:0.7926 AUROC:0.8741 Precision:0.7700 Recall:0.8344 F1:0.8009 AUPR:0.8633
# Epoch:698 Train_loss:3.7019 ACC:0.7919 AUROC:0.8734 Precision:0.7686 Recall:0.8351 F1:0.8005 AUPR:0.8626
# Epoch:699 Train_loss:3.6826 ACC:0.7944 AUROC:0.8751 Precision:0.7720 Recall:0.8356 F1:0.8025 AUPR:0.8642
# Epoch:700 Train_loss:3.6695 ACC:0.7947 AUROC:0.8762 Precision:0.7713 Recall:0.8380 F1:0.8032 AUPR:0.8637
# Epoch:700 Val_loss:3.6984 ACC:0.7963 AUROC:0.8736 Precision:0.7748 Recall:0.8354 F1:0.8040 AUPR:0.8573
# ==> Saving model...
# Epoch:701 Train_loss:3.6958 ACC:0.7927 AUROC:0.8739 Precision:0.7701 Recall:0.8345 F1:0.8010 AUPR:0.8617
# Epoch:702 Train_loss:3.6728 ACC:0.7930 AUROC:0.8755 Precision:0.7703 Recall:0.8352 F1:0.8014 AUPR:0.8638
# Epoch:703 Train_loss:3.6927 ACC:0.7927 AUROC:0.8739 Precision:0.7687 Recall:0.8373 F1:0.8015 AUPR:0.8623
# Epoch:704 Train_loss:3.6841 ACC:0.7936 AUROC:0.8747 Precision:0.7713 Recall:0.8348 F1:0.8018 AUPR:0.8628
# Epoch:705 Train_loss:3.6915 ACC:0.7927 AUROC:0.8744 Precision:0.7704 Recall:0.8339 F1:0.8009 AUPR:0.8630
# Epoch:705 Val_loss:3.7269 ACC:0.7884 AUROC:0.8712 Precision:0.7696 Recall:0.8227 F1:0.7953 AUPR:0.8565
# Epoch:706 Train_loss:3.6802 ACC:0.7931 AUROC:0.8751 Precision:0.7707 Recall:0.8344 F1:0.8013 AUPR:0.8634
# Epoch:707 Train_loss:3.6821 ACC:0.7920 AUROC:0.8750 Precision:0.7681 Recall:0.8367 F1:0.8009 AUPR:0.8636
# Epoch:708 Train_loss:3.6802 ACC:0.7935 AUROC:0.8752 Precision:0.7712 Recall:0.8346 F1:0.8017 AUPR:0.8640
# Epoch:709 Train_loss:3.6960 ACC:0.7925 AUROC:0.8736 Precision:0.7686 Recall:0.8369 F1:0.8013 AUPR:0.8612
# Epoch:710 Train_loss:3.6779 ACC:0.7936 AUROC:0.8755 Precision:0.7711 Recall:0.8351 F1:0.8018 AUPR:0.8639
# Epoch:710 Val_loss:3.7388 ACC:0.7896 AUROC:0.8704 Precision:0.7755 Recall:0.8148 F1:0.7947 AUPR:0.8558
# ==> Saving model...

# %% [markdown]
# To test the model you just trained, you need to prepare a test dataset 'test.csv' and model parameters 'seq-level_parameters'

# %%
df = run_antigenHLAII_seq.Inference('./test_antigenHLAII/Data/sequence/test.csv', model_path='./antigenHLAII_training_log/seq-level_parameters.pt')

# %%
df

# %%
#Draw ROC curve
score_list=list(df['score'])
label_list=list(df['label'])
hhList=[]
LegendLabels=[]
plt.figure(figsize=(9,9))
font = {'weight' : 'normal',
'size'   : 20}
mpl.rc('font', **font)
fpr, tpr, thersholds = roc_curve(label_list, score_list, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot([0,1],[0,1],ls='dashed',lw=3, color='whitesmoke')
hh, = plt.plot(fpr, tpr, color='#0675B4', lw=3)
hhList.append(hh)
LegendLabels.append('deepAntigen_seq'+'(AUC:'+str(round(roc_auc,2))+')')
plt.xlabel('1-Specificity')
plt.ylabel('Sensitivity')
plt.title('ROC Curve')
legend=plt.legend(hhList,LegendLabels)
plt.show()

# %% [markdown]
# ## Inference anitgen-HLAII binding at the atom level using deepAntigen

# %% [markdown]
# By utilizing parameters provided by us, you can directly predict atom-level contact between antigen and HLAII, requiring only the preparation of the test dataset 'sample.csv'. Although inferring atom-level contact, deepAntigen only requires the residue sequences of antigen and HLAII as inputs.

# %%
peptide_atoms, HLAII_atoms, contact_maps = run_antigenHLAII_atom.Inference('./test_antigenHLAII/Data/crystal_structure/sample.csv')

# %% [markdown]
# The x-axis and y-axis respectively display top-10 crucial atoms of HLA and peptide. The heatmap represents the contact probabilities between these atoms.

# %% [markdown]
# ## Fine-tune deepAntigen using antigen-HLAII crystal structure data

# %% [markdown]
# Preprocess .pdb file in the directory 'pdb' download from Protein Data Bank according meta infomation provided in 'info_noredudant.csv'.

# %%
process_pdb_absolute('./test_antigenHLAII/Data/crystal_structure/pdb', './test_antigenHLAII/Data/crystal_structure/info_noredudant.csv')

# %% [markdown]
# Because residue IDs of alpha and beta chains in HLAII are repeative, we renumber residues to distinguish them by following steps.

# %%
process_pdb_relative('./test_antigenHLAII/Data/crystal_structure/pdb', './test_antigenHLAII/Data/crystal_structure/info_noredudant.csv')

# %% [markdown]
# Calculate pairwise distance between atoms on antigen and HLAII for each crystal structure.

# %%
calculate_distance('./test_antigenHLAII/Data/crystal_structure/pdb_Extracted_relative/')

# %% [markdown]
# Then, you can utilize structural information to fine-tuen model that you have pre-trained using sequence-level binding data. You can alter hyperparameters in 'config_atom.ini', and then start fine-tuning.

# %%
run_antigenHLAII_atom.Train('./test_antigenHLAII/Data/crystal_structure/info_noredudant.csv', config_path='./test_antigenHLAII/config_atom.ini')

# %% [markdown]
# Two heatmaps are respectively true distances and contact probabilities between atoms on antigen and HLAII. We only exhibit the results of leaving 3w0w for validation, while the remaining crystal structures were used for training
